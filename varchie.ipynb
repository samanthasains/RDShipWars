# %%
import tweepy
import pandas as pd

# %%
# %run ./varchiekeys.ipynb

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
number_of_tweets = 15000
tweets = []
quote_status = []
lang = []
favorite_count = []
retweet_count = []
time = []
tweet_id = []

for i in tweepy.Cursor(api.search, q = "time jump Riverdale", tweet_mode="extended", wait_on_rate_limit="True").items(number_of_tweets):
    tweets.append(i.full_text)
    quote_status.append(i.is_quote_status)
    lang.append(i.lang)
    favorite_count.append(i.favorite_count)
    retweet_count.append(i.retweet_count)
    time.append(i.created_at)
    tweet_id.append(i.id)

# %%
df = pd.DataFrame({'tweets': tweets, 'quote_status': quote_status, 'language': lang, 'favorite_count': favorite_count, 'retweet_count': retweet_count, 'time':time, "id":tweet_id})

# %%
df
# Out:
#                                                  tweets  quote_status  \
# 0     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# 1     RT @TheWyrmQueen: Toni Topaz \n\n-Riverdale rp...         False
# 2     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# 3     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# 4     RT @BusinessOfLodge: Veronica Lodge \n\nlitera...         False
# ...                                                 ...           ...
# 1064  Riverdale time jump said 🤡 “my family acknowle...         False
# 1065  @the_moviebob I stopped watching Riverdale for...         False
# 1066  RT @YoungEntmag: The time jump in the latest @...         False
# 1067  RT @venereumadlicio: ˏˋ     𝑯𝑨𝑽𝑬 𝑻𝑯𝑬 𝑳𝑨𝑴𝑩𝑺    ...         False
# 1068  ngl riverdale has got a different vibe in the ...         False
#
#      language  favorite_count  retweet_count                time  \
# ...

# %%
df.drop_duplicates(subset='tweets', inplace=True)

# %%
df
# Out:
#                                                  tweets  quote_status  \
# 0     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# 1     RT @TheWyrmQueen: Toni Topaz \n\n-Riverdale rp...         False
# 4     RT @BusinessOfLodge: Veronica Lodge \n\nlitera...         False
# 13    will I understand Riverdale new season if I on...         False
# 21    @Twirl4meK @slowburnsftw "Seven years later......         False
# ...                                                 ...           ...
# 1063  @topazgotjuice @ashiimp4 Favorite character on...         False
# 1064  Riverdale time jump said 🤡 “my family acknowle...         False
# 1065  @the_moviebob I stopped watching Riverdale for...         False
# 1066  RT @YoungEntmag: The time jump in the latest @...         False
# 1068  ngl riverdale has got a different vibe in the ...         False
#
#      language  favorite_count  retweet_count                time  \
# ...

# %%
df=df[df.language =="en"]

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                 tweets  quote_status language  \
# 0    RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
# 1    RT @TheWyrmQueen: Toni Topaz \n\n-Riverdale rp...         False       en
# 2    RT @BusinessOfLodge: Veronica Lodge \n\nlitera...         False       en
# 3    will I understand Riverdale new season if I on...         False       en
# 4    @Twirl4meK @slowburnsftw "Seven years later......         False       en
# ..                                                 ...           ...      ...
# 362  @topazgotjuice @ashiimp4 Favorite character on...         False       en
# 363  Riverdale time jump said 🤡 “my family acknowle...         False       en
# 364  @the_moviebob I stopped watching Riverdale for...         False       en
# 365  RT @YoungEntmag: The time jump in the latest @...         False       en
# 366  ngl riverdale has got a different vibe in the ...         False       en
#
# ...

# %%
df.to_csv('RDShipWars/time_jump.csv', index=False)

# %%
df
# Out:
#                                                 tweets  quote_status language  \
# 0    RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
# 1    RT @TheWyrmQueen: Toni Topaz \n\n-Riverdale rp...         False       en
# 2    RT @BusinessOfLodge: Veronica Lodge \n\nlitera...         False       en
# 3    will I understand Riverdale new season if I on...         False       en
# 4    @Twirl4meK @slowburnsftw "Seven years later......         False       en
# ..                                                 ...           ...      ...
# 362  @topazgotjuice @ashiimp4 Favorite character on...         False       en
# 363  Riverdale time jump said 🤡 “my family acknowle...         False       en
# 364  @the_moviebob I stopped watching Riverdale for...         False       en
# 365  RT @YoungEntmag: The time jump in the latest @...         False       en
# 366  ngl riverdale has got a different vibe in the ...         False       en
#
# ...

# %%
number_of_tweets = 15000
tweets = []
quote_status = []
lang = []
favorite_count = []
retweet_count = []
time = []
tweet_id = []

for i in tweepy.Cursor(api.search, q = "choni", tweet_mode="extended", wait_on_rate_limit="True").items(number_of_tweets):
    tweets.append(i.full_text)
    quote_status.append(i.is_quote_status)
    lang.append(i.lang)
    favorite_count.append(i.favorite_count)
    retweet_count.append(i.retweet_count)
    time.append(i.created_at)
    tweet_id.append(i.id)

# %%
choni_df = pd.DataFrame({'tweets': tweets, 'quote_status': quote_status, 'language': lang, 'favorite_count': favorite_count, 'retweet_count': retweet_count, 'time':time, "id":tweet_id})

# %%
choni_df
# Out:
#                                                  tweets  quote_status  \
# 0     RT @chonigif: the roles have been reversed 👀\n...         False
# 1     RT @BarchieUpdates: Rachel Talalay directed th...         False
# 2     Stop. Shipping. Cheryl. With. Men. She. Is. A....         False
# 3     RT @chonistyles: CHONI ARE THE MAIN STORYLINE ...         False
# 4     RT @chonistyles: CHONI ARE THE MAIN STORYLINE ...         False
# ...                                                 ...           ...
# 1875  @rcnnnie Give me Choni over B*rchie sex any da...         False
# 1876  I'm sorry but barchie got two sex scenes durin...         False
# 1877  PORRA COMO ASSIM FILHOS DA PUTA ARROMBADOS E M...          True
# 1878  @chonicarrington Omg yes and barchie having mo...         False
# 1879  Finna pull a little nappy nap and try to dream...         False
#
#      language  favorite_count  retweet_count                time  \
# ...

# %%
choni_df.drop_duplicates(subset='tweets', inplace=True)
# Out:
# <ipython-input-38-17d2539d5604>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   choni_df.drop_duplicates(subset='tweets', inplace=True)

# %%
choni_df
# Out:
#                                                  tweets  quote_status  \
# 0     RT @chonigif: the roles have been reversed 👀\n...         False
# 1     RT @BarchieUpdates: Rachel Talalay directed th...         False
# 2     Stop. Shipping. Cheryl. With. Men. She. Is. A....         False
# 3     RT @chonistyles: CHONI ARE THE MAIN STORYLINE ...         False
# 10                RT @tcpazs: barchie and choni besties          True
# ...                                                 ...           ...
# 1874  @rcnnnie As much as I do like some of the het ...         False
# 1875  @rcnnnie Give me Choni over B*rchie sex any da...         False
# 1876  I'm sorry but barchie got two sex scenes durin...         False
# 1878  @chonicarrington Omg yes and barchie having mo...         False
# 1879  Finna pull a little nappy nap and try to dream...         False
#
#      language  favorite_count  retweet_count                time  \
# ...

# %%
choni_df=choni_df[choni_df.language =="en"]

# %%
choni_df
# Out:
#                                                  tweets  quote_status  \
# 0     RT @chonigif: the roles have been reversed 👀\n...         False
# 1     RT @BarchieUpdates: Rachel Talalay directed th...         False
# 2     Stop. Shipping. Cheryl. With. Men. She. Is. A....         False
# 3     RT @chonistyles: CHONI ARE THE MAIN STORYLINE ...         False
# 10                RT @tcpazs: barchie and choni besties          True
# ...                                                 ...           ...
# 1874  @rcnnnie As much as I do like some of the het ...         False
# 1875  @rcnnnie Give me Choni over B*rchie sex any da...         False
# 1876  I'm sorry but barchie got two sex scenes durin...         False
# 1878  @chonicarrington Omg yes and barchie having mo...         False
# 1879  Finna pull a little nappy nap and try to dream...         False
#
#      language  favorite_count  retweet_count                time  \
# ...

# %%
choni_df.drop_duplicates(subset='tweets', inplace=True)
# Out:
# <ipython-input-37-17d2539d5604>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   choni_df.drop_duplicates(subset='tweets', inplace=True)

# %%
choni_df=choni_df.reset_index(drop=True)

# %%
choni_df
# Out:
#                                                 tweets  quote_status language  \
# 0    RT @chonigif: the roles have been reversed 👀\n...         False       en
# 1    RT @BarchieUpdates: Rachel Talalay directed th...         False       en
# 2    Stop. Shipping. Cheryl. With. Men. She. Is. A....         False       en
# 3    RT @chonistyles: CHONI ARE THE MAIN STORYLINE ...         False       en
# 4                RT @tcpazs: barchie and choni besties          True       en
# ..                                                 ...           ...      ...
# 697  @rcnnnie As much as I do like some of the het ...         False       en
# 698  @rcnnnie Give me Choni over B*rchie sex any da...         False       en
# 699  I'm sorry but barchie got two sex scenes durin...         False       en
# 700  @chonicarrington Omg yes and barchie having mo...         False       en
# 701  Finna pull a little nappy nap and try to dream...         False       en
#
# ...

# %%
choni_df.to_csv('RDShipWars/choni.csv', index=False)

# %%
number_of_tweets = 15000
tweets = []
quote_status = []
lang = []
favorite_count = []
retweet_count = []
time = []
tweet_id = []

for i in tweepy.Cursor(api.search, q = "varchie", tweet_mode="extended", wait_on_rate_limit="True").items(number_of_tweets):
    tweets.append(i.full_text)
    quote_status.append(i.is_quote_status)
    lang.append(i.lang)
    favorite_count.append(i.favorite_count)
    retweet_count.append(i.retweet_count)
    time.append(i.created_at)
    tweet_id.append(i.id)

# %%
varchie_df = pd.DataFrame({'tweets': tweets, 'quote_status': quote_status, 'language': lang, 'favorite_count': favorite_count, 'retweet_count': retweet_count, 'time':time, "id":tweet_id})

# %%
varchie_df
# Out:
#                                                  tweets  quote_status  \
# 0     RT @bettyandarchie4: If you are worried about ...         False
# 1     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# 2     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# 3     RT @vcrchies: COME BACK TO ME, VARCHIE. YOUR S...         False
# 4     I'm rewatching some #bughead scenes and I'm ki...         False
# ...                                                 ...           ...
# 6141  we could've gotten a second varchie shower sce...         False
# 6142  pretending this is varchie. https://t.co/3oGLt...         False
# 6143  Varchie in the promo of episode 506 🥰 https://...         False
# 6144  RT @barcheated: What if varchie and bughead ho...         False
# 6145  RT @ssabasays: Riverdale writers literally jus...         False
#
#      language  favorite_count  retweet_count                time  \
# ...

# %%
varchie_df.drop_duplicates(subset='tweets', inplace=True)

# %%
varchie_df=varchie_df[varchie_df.language =="en"]

# %%
varchie_df
# Out:
#                                                  tweets  quote_status  \
# 0     RT @bettyandarchie4: If you are worried about ...         False
# 1     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# 3     RT @vcrchies: COME BACK TO ME, VARCHIE. YOUR S...         False
# 4     I'm rewatching some #bughead scenes and I'm ki...         False
# 9     RT @winchesterbitxh: barchie has more chemistr...         False
# ...                                                 ...           ...
# 6140  i believe in the key party theory, varchie and...         False
# 6141  we could've gotten a second varchie shower sce...         False
# 6142  pretending this is varchie. https://t.co/3oGLt...         False
# 6143  Varchie in the promo of episode 506 🥰 https://...         False
# 6145  RT @ssabasays: Riverdale writers literally jus...         False
#
#      language  favorite_count  retweet_count                time  \
# ...

# %%
varchie_df.to_csv('RDShipWars/varchie.csv', index=False)

# %%
number_of_tweets = 15000
tweets = []
quote_status = []
lang = []
favorite_count = []
retweet_count = []
time = []
tweet_id = []

for i in tweepy.Cursor(api.search, q = "falice", tweet_mode="extended", wait_on_rate_limit="True").items(number_of_tweets):
    tweets.append(i.full_text)
    quote_status.append(i.is_quote_status)
    lang.append(i.lang)
    favorite_count.append(i.favorite_count)
    retweet_count.append(i.retweet_count)
    time.append(i.created_at)
    tweet_id.append(i.id)

# %%
falice_df = pd.DataFrame({'tweets': tweets, 'quote_status': quote_status, 'language': lang, 'favorite_count': favorite_count, 'retweet_count': retweet_count, 'time':time, "id":tweet_id})

# %%
falice_df
# Out:
#                                                 tweets  quote_status language  \
# 0    RT @softfalice: melissa and joey moments that ...         False       en
# 1    @mishacollins\n lets sue the Riverdale writers...         False       en
# 2    @mishacollins lets sue the Riverdale writers a...         False       en
# 3    The pinky TEASE, I miss season 2 falice https:...          True       en
# 4    RT @amicksbabe: I want fp’s letter @RiverdaleW...         False       en
# ..                                                 ...           ...      ...
# 348              @PRiveerdale CHONI, BERONICA Y FALICE         False       es
# 349                  Faliće mi https://t.co/4oidqRUkC7         False      und
# 350  @barchiesdreams Honestly id replace veggie wit...         False       en
# 351  @PRiveerdale Bughead and choni\n\nAnd young fa...         False       en
# 352  Haven’t seen the falice scene in far to long p...         False       en
#
# ...

# %%
falice_df.drop_duplicates(subset='tweets', inplace=True)

# %%
falice_df=falice_df[falice_df.language =="en"]

# %%
falice_df
# Out:
#                                                 tweets  quote_status language  \
# 0    RT @softfalice: melissa and joey moments that ...         False       en
# 1    @mishacollins\n lets sue the Riverdale writers...         False       en
# 2    @mishacollins lets sue the Riverdale writers a...         False       en
# 3    The pinky TEASE, I miss season 2 falice https:...          True       en
# 4    RT @amicksbabe: I want fp’s letter @RiverdaleW...         False       en
# ..                                                 ...           ...      ...
# 344                     @dioramick how’s falice doing?         False       en
# 345  RT @barchie_stan: rt if you wanna be mutuals👉🏻...         False       en
# 350  @barchiesdreams Honestly id replace veggie wit...         False       en
# 351  @PRiveerdale Bughead and choni\n\nAnd young fa...         False       en
# 352  Haven’t seen the falice scene in far to long p...         False       en
#
# ...

# %%
falice_df.to_csv('RDShipWars/falice.csv', index=False)

# %%
falice_df
# Out:
#                                                 tweets  quote_status language  \
# 0    RT @softfalice: melissa and joey moments that ...         False       en
# 1    @mishacollins\n lets sue the Riverdale writers...         False       en
# 2    @mishacollins lets sue the Riverdale writers a...         False       en
# 3    The pinky TEASE, I miss season 2 falice https:...          True       en
# 4    RT @amicksbabe: I want fp’s letter @RiverdaleW...         False       en
# ..                                                 ...           ...      ...
# 344                     @dioramick how’s falice doing?         False       en
# 345  RT @barchie_stan: rt if you wanna be mutuals👉🏻...         False       en
# 350  @barchiesdreams Honestly id replace veggie wit...         False       en
# 351  @PRiveerdale Bughead and choni\n\nAnd young fa...         False       en
# 352  Haven’t seen the falice scene in far to long p...         False       en
#
# ...

# %%
number_of_tweets = 15000
tweets = []
quote_status = []
lang = []
favorite_count = []
retweet_count = []
time = []
tweet_id = []

for i in tweepy.Cursor(api.search, q = "cheronica", tweet_mode="extended", wait_on_rate_limit="True").items(number_of_tweets):
    tweets.append(i.full_text)
    quote_status.append(i.is_quote_status)
    lang.append(i.lang)
    favorite_count.append(i.favorite_count)
    retweet_count.append(i.retweet_count)
    time.append(i.created_at)
    tweet_id.append(i.id)

# %%
cheronica_df = pd.DataFrame({'tweets': tweets, 'quote_status': quote_status, 'language': lang, 'favorite_count': favorite_count, 'retweet_count': retweet_count, 'time':time, "id":tweet_id})

# %%
cheronica_df.drop_duplicates(subset='tweets', inplace=True)

# %%
cheronica_df
# Out:
#                                                 tweets  quote_status language  \
# 0     cheronica is hot why lie https://t.co/kAR7kTcd1D          True       en
# 1                         @tiedu2me OMGGG CHERONICA !!         False       en
# 2    RT @choniswitches2: I’ll leave the fandom. my ...          True       en
# 3    I’ll leave the fandom. my nerves i can take bu...          True       en
# 4    achei um monte de fanfic cheronica, ganhei o diab         False       pt
# ..                                                 ...           ...      ...
# 104  Isso aqui foi o Jughead fingindo que morreu a ...          True       pt
# 105  @lamercenairex i watched bf, i will watch give...         False       en
# 106                            @barchiecakes cheronica         False       es
# 107  no bc at this point i will take just about any...         False       en
# 108  @chonismaid exactly and toni doesn’t even have...         False       en
#
# ...

# %%
cheronica_df=cheronica_df[cheronica_df.language =="en"]

# %%
cheronica_df
# Out:
#                                                 tweets  quote_status language  \
# 0     cheronica is hot why lie https://t.co/kAR7kTcd1D          True       en
# 1                         @tiedu2me OMGGG CHERONICA !!         False       en
# 2    RT @choniswitches2: I’ll leave the fandom. my ...          True       en
# 3    I’ll leave the fandom. my nerves i can take bu...          True       en
# 6    waiting for my cheronica scenes https://t.co/B...         False       en
# ..                                                 ...           ...      ...
# 100  @jessdamnday hahaha ur good\n- top fav charact...         False       en
# 101  @klainescandIes — top fav characters:\n1.veron...         False       en
# 105  @lamercenairex i watched bf, i will watch give...         False       en
# 107  no bc at this point i will take just about any...         False       en
# 108  @chonismaid exactly and toni doesn’t even have...         False       en
#
# ...

# %%
cheronica_df.to_csv('RDShipWars/cheronica.csv', index=False)

# %%
cheronica_df
# Out:
#                                                 tweets  quote_status language  \
# 0     cheronica is hot why lie https://t.co/kAR7kTcd1D          True       en
# 1                         @tiedu2me OMGGG CHERONICA !!         False       en
# 2    RT @choniswitches2: I’ll leave the fandom. my ...          True       en
# 3    I’ll leave the fandom. my nerves i can take bu...          True       en
# 6    waiting for my cheronica scenes https://t.co/B...         False       en
# ..                                                 ...           ...      ...
# 100  @jessdamnday hahaha ur good\n- top fav charact...         False       en
# 101  @klainescandIes — top fav characters:\n1.veron...         False       en
# 105  @lamercenairex i watched bf, i will watch give...         False       en
# 107  no bc at this point i will take just about any...         False       en
# 108  @chonismaid exactly and toni doesn’t even have...         False       en
#
# ...

# %%
number_of_tweets = 15000
tweets = []
quote_status = []
lang = []
favorite_count = []
retweet_count = []
time = []
tweet_id = []

for i in tweepy.Cursor(api.search, q = "tughead", tweet_mode="extended", wait_on_rate_limit="True").items(number_of_tweets):
    tweets.append(i.full_text)
    quote_status.append(i.is_quote_status)
    lang.append(i.lang)
    favorite_count.append(i.favorite_count)
    retweet_count.append(i.retweet_count)
    time.append(i.created_at)
    tweet_id.append(i.id)

# %%
tughead_df = pd.DataFrame({'tweets': tweets, 'quote_status': quote_status, 'language': lang, 'favorite_count': favorite_count, 'retweet_count': retweet_count, 'time':time, "id":tweet_id})

# %%
tughead_df
# Out:
#                                                tweets  quote_status language  \
# 0   I ship Jughead and Tabitha.\n\nWhat would that...         False       en
# 1   RT @karyv_mp: @mgom_lp Tughead...wait no, that...         False       en
# 2   @mgom_lp Tughead...wait no, that was Toni and ...         False       en
# 3   they’re setting tabithajones up just like they...         False       en
# 4   RT @Barchie18love: My thoughts.\n\n#barchie #r...         False       en
# 5                                 A- kiero tughead 👍😫         False       es
# 6          @rihdayaa i hope it sticks and not tughead         False       en
# 7   @Recap_Rewind @CW_Riverdale Loved it. #Riverda...         False       en
# 8   @reinhtirst Tabihead= tabitha+jughead\n\nTughe...         False       et
# 9   pra quem shippa tughead, vcs acham que a tabit...         False       pt
# 10  @RiverdaleDark Surely the correct term would b...         False       en
# ...

# %%
tughead_df.drop_duplicates(subset='tweets', inplace=True)

# %%
tughead_df=tughead_df[tughead_df.language =="en"]

# %%
tughead_df
# Out:
#                                                tweets  quote_status language  \
# 0   I ship Jughead and Tabitha.\n\nWhat would that...         False       en
# 1   RT @karyv_mp: @mgom_lp Tughead...wait no, that...         False       en
# 2   @mgom_lp Tughead...wait no, that was Toni and ...         False       en
# 3   they’re setting tabithajones up just like they...         False       en
# 4   RT @Barchie18love: My thoughts.\n\n#barchie #r...         False       en
# 6          @rihdayaa i hope it sticks and not tughead         False       en
# 7   @Recap_Rewind @CW_Riverdale Loved it. #Riverda...         False       en
# 10  @RiverdaleDark Surely the correct term would b...         False       en
# 30  RT @msprousexz: tughead means home🤲💕 https://t...         False       en
# 31       tughead means home🤲💕 https://t.co/Iinq3dxFfx         False       en
# 33  @Paublossom1 @lilireinhart People say their sh...         False       en
# ...

# %%
tughead_df.to_csv('tughead.csv', index=False)

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/christinemagnotta/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
sid = SentimentIntensityAnalyzer()

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
#df['rating'] = df['tweets'].apply(analyzer.polarity_scores)
#pd.concat([df.drop(['rating'], axis=1), df['rating'].apply(pd.Series)], axis=1)

#df = time jump
#choni_df
#varchie_df
#falice_df
#cheronica_df
#tughead_df

# %%
df['rating'] = df['tweets'].apply(analyzer.polarity_scores)
pd.concat([df.drop(['rating'], axis=1), df['rating'].apply(pd.Series)], axis=1)
# Out:
#                                                 tweets  quote_status language  \
# 0    RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
# 1    RT @TheWyrmQueen: Toni Topaz \n\n-Riverdale rp...         False       en
# 2    RT @BusinessOfLodge: Veronica Lodge \n\nlitera...         False       en
# 3    will I understand Riverdale new season if I on...         False       en
# 4    @Twirl4meK @slowburnsftw "Seven years later......         False       en
# ..                                                 ...           ...      ...
# 362  @topazgotjuice @ashiimp4 Favorite character on...         False       en
# 363  Riverdale time jump said 🤡 “my family acknowle...         False       en
# 364  @the_moviebob I stopped watching Riverdale for...         False       en
# 365  RT @YoungEntmag: The time jump in the latest @...         False       en
# 366  ngl riverdale has got a different vibe in the ...         False       en
#
# ...

# %%
#choni_df

choni_df['rating'] = choni_df['tweets'].apply(analyzer.polarity_scores)
pd.concat([choni_df.drop(['rating'], axis=1), choni_df['rating'].apply(pd.Series)], axis=1)
# Out:
#                                                 tweets  quote_status language  \
# 0    RT @chonigif: the roles have been reversed 👀\n...         False       en
# 1    RT @BarchieUpdates: Rachel Talalay directed th...         False       en
# 2    Stop. Shipping. Cheryl. With. Men. She. Is. A....         False       en
# 3    RT @chonistyles: CHONI ARE THE MAIN STORYLINE ...         False       en
# 4                RT @tcpazs: barchie and choni besties          True       en
# ..                                                 ...           ...      ...
# 697  @rcnnnie As much as I do like some of the het ...         False       en
# 698  @rcnnnie Give me Choni over B*rchie sex any da...         False       en
# 699  I'm sorry but barchie got two sex scenes durin...         False       en
# 700  @chonicarrington Omg yes and barchie having mo...         False       en
# 701  Finna pull a little nappy nap and try to dream...         False       en
#
# ...

# %%
varchie_df['rating'] = varchie_df['tweets'].apply(analyzer.polarity_scores)
pd.concat([varchie_df.drop(['rating'], axis=1), varchie_df['rating'].apply(pd.Series)], axis=1)
# Out:
# <ipython-input-118-f8abbdd29423>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   varchie_df['rating'] = varchie_df['tweets'].apply(analyzer.polarity_scores)
#                                                  tweets  quote_status  \
# 0     RT @bettyandarchie4: If you are worried about ...         False
# 1     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# 3     RT @vcrchies: COME BACK TO ME, VARCHIE. YOUR S...         False
# 4     I'm rewatching some #bughead scenes and I'm ki...         False
# 9     RT @winchesterbitxh: barchie has more chemistr...         False
# ...                                                 ...           ...
# 6140  i believe in the key party theory, varchie and...         False
# ...

# %%
#falice_df
falice_df['rating'] = falice_df['tweets'].apply(analyzer.polarity_scores)
pd.concat([falice_df.drop(['rating'], axis=1), falice_df['rating'].apply(pd.Series)], axis=1)
# Out:
#                                                 tweets  quote_status language  \
# 0    RT @softfalice: melissa and joey moments that ...         False       en
# 1    @mishacollins\n lets sue the Riverdale writers...         False       en
# 2    @mishacollins lets sue the Riverdale writers a...         False       en
# 3    The pinky TEASE, I miss season 2 falice https:...          True       en
# 4    RT @amicksbabe: I want fp’s letter @RiverdaleW...         False       en
# ..                                                 ...           ...      ...
# 344                     @dioramick how’s falice doing?         False       en
# 345  RT @barchie_stan: rt if you wanna be mutuals👉🏻...         False       en
# 350  @barchiesdreams Honestly id replace veggie wit...         False       en
# 351  @PRiveerdale Bughead and choni\n\nAnd young fa...         False       en
# 352  Haven’t seen the falice scene in far to long p...         False       en
#
# ...

# %%
cheronica_df['rating'] = cheronica_df['tweets'].apply(analyzer.polarity_scores)
pd.concat([cheronica_df.drop(['rating'], axis=1), cheronica_df['rating'].apply(pd.Series)], axis=1)
# Out:
# <ipython-input-120-bd0f0f934bff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cheronica_df['rating'] = cheronica_df['tweets'].apply(analyzer.polarity_scores)
#                                                 tweets  quote_status language  \
# 0     cheronica is hot why lie https://t.co/kAR7kTcd1D          True       en
# 1                         @tiedu2me OMGGG CHERONICA !!         False       en
# 2    RT @choniswitches2: I’ll leave the fandom. my ...          True       en
# 3    I’ll leave the fandom. my nerves i can take bu...          True       en
# 6    waiting for my cheronica scenes https://t.co/B...         False       en
# ..                                                 ...           ...      ...
# ...

# %%
tughead_df['rating'] = tughead_df['tweets'].apply(analyzer.polarity_scores)
pd.concat([tughead_df.drop(['rating'], axis=1), tughead_df['rating'].apply(pd.Series)], axis=1)
# Out:
# <ipython-input-121-cca8cb73543c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tughead_df['rating'] = tughead_df['tweets'].apply(analyzer.polarity_scores)
#                                                tweets  quote_status language  \
# 0   I ship Jughead and Tabitha.\n\nWhat would that...         False       en
# 1   RT @karyv_mp: @mgom_lp Tughead...wait no, that...         False       en
# 2   @mgom_lp Tughead...wait no, that was Toni and ...         False       en
# 3   they’re setting tabithajones up just like they...         False       en
# 4   RT @Barchie18love: My thoughts.\n\n#barchie #r...         False       en
# 6          @rihdayaa i hope it sticks and not tughead         False       en
# ...

# %%
#analyzer = SentimentIntensityAnalyzer()
#df['compound'] = [analyzer.polarity_scores(x)['compound'] for x in df['tweets']]
#df['neg'] = [analyzer.polarity_scores(x)['neg'] for x in df['tweets']]
#df['neu'] = [analyzer.polarity_scores(x)['neu'] for x in df['tweets']]
#df['pos'] = [analyzer.polarity_scores(x)['pos'] for x in df['tweets']]

# %%
tughead_df.to_csv('/Users/christinemagnotta/RDShipWars/tughead2.csv', index=False)

# %%
#df = time jump
#choni_df
#varchie_df
#falice_df
#cheronica_df

# %%
choni_df.to_csv('/Users/christinemagnotta/RDShipWars/choni_df2.csv', index=False)

# %%
varchie_df.to_csv('/Users/christinemagnotta/RDShipWars/varchie_df2.csv', index=False)

# %%
falice_df.to_csv('/Users/christinemagnotta/RDShipWars/falice_df2.csv', index=False)

# %%
cheronica_df.to_csv('/Users/christinemagnotta/RDShipWars/cheronica_df.csv', index=False)
