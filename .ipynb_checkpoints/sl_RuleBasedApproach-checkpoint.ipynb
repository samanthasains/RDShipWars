# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
import re
import emoji
import nltk
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
import numpy as np
import nltk
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
choni_csv = pd.read_csv('bughead_new.csv.csv');
choni_csv.head(10)
# Out:
#                                               tweets  quote_status language  \
# 0  Bughead was never meant to be a main couple on...         False       en
# 1                   (especially on bughead day) HELP         False       en
# 2  her little smile after it END OF DISCUSSION BU...         False       en
# 3  RT @lovemesometopaz: if you still think bughea...         False       en
# 4  RT @BugheadGif: four years ago today, jughead ...         False       en
# 5  RT @mitchelsdemhawk: hating on bughead and var...         False       en
# 6  RT @bugheadaIe: saying bughead was never suppo...         False       en
# 7               RAS is a huge Bughead, he has taste.         False       en
# 8  RT @BugheadUpdates: 4 years ago today, Jughead...         False       en
# 9  RT @BamSmackPow: On this day we celebrate one ...         False       en
#
#    favorite_count  retweet_count                 time                   id  \
# 0               0              0  2021-03-03 00:56:53  1366915446918828033
# 1               0              0  2021-03-03 00:56:50  1366915433287217152
# 2               3              0  2021-03-03 00:54:58  1366914965056192515
# 3               0             97  2021-03-03 00:54:34  1366914865089101832
# 4               0             74  2021-03-03 00:54:13  1366914777289744384
# 5               0              2  2021-03-03 00:45:22  1366912550407983112
# 6               0             31  2021-03-03 00:43:18  1366912029840318466
# 7               1              0  2021-03-03 00:42:19  1366911780702875651
# 8               0            153  2021-03-03 00:41:24  1366911550875926531
# 9               0             14  2021-03-03 00:38:30  1366910822807658496
#
#                                               rating  \
# 0  {'neg': 0.126, 'neu': 0.834, 'pos': 0.04, 'com...
# 1  {'neg': 0.0, 'neu': 0.538, 'pos': 0.462, 'comp...
# 2  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 0.76, 'pos': 0.24, 'compou...
# 5  {'neg': 0.191, 'neu': 0.809, 'pos': 0.0, 'comp...
# 6  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7  {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'comp...
# 8  {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'comp...
# 9  {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'comp...
#
#                                       processed_text  \
# 0  ['bughead', 'never', 'meant', 'main', 'couple'...
# 1           ['especially', 'bughead', 'day', 'help']
# 2  ['little', 'smile', 'end', 'discussion', 'bugh...
# 3  ['still', 'think', 'bughead', 'always', 'suppo...
# 4  ['four', 'years', 'ago', 'today', 'jughead', '...
# 5  ['hating', 'bughead', 'varchie', 'serve', 'yal...
# 6  ['saying', 'bughead', 'never', 'supposed', 'ma...
# 7                ['ras', 'huge', 'bughead', 'taste']
# 8  ['4', 'years', 'ago', 'today', 'jughead', 'cli...
# 9  ['day', 'celebrate', 'one', 'riverdale', 'endg...
#
#                                       cleaned_tweets
# 0  bughead never meant main couple show yes liter...
# 1                        especially bughead day help
# 2        little smile end discussion bughead endgame
# 3  still think bughead always supposed main coupl...
# 4  four years ago today jughead jones climbed bet...
# 5            hating bughead varchie serve yall think
# 6  saying bughead never supposed main couple espe...
# 7                             ras huge bughead taste
# 8  4 years ago today jughead climbed betty window...
# 9  day celebrate one riverdale endgame couples ha...

# %%
# Rule-based approach
posTokens = ["love", "sexy", "hot", "good", "perfect", "beautiful", "like", "sexi", "sexxy", "luv", "fav", "favorite", "riot", 
             "endgame", "great", "happy"]
negTokens = ["beef", "choke", "fail", "barf", "hate", "yasss", "trash", "disgusting", "quit", "give up", "boring", "boring", 
             "ugly", "dumb", "hatred", "tsk", "...", "bad"]
sentimentPos = []
sentimentNeg = []
sentimentNeu = []

emoteToken = {
  ":smile:":"positive", ":simple_smile:":"positive", ":laughing:":"positive", ":blush:":"positive", ":heart_eyes:":"positive", 
    ":smirk:":"positive", ":starstruck:":"positive", ":kissing_heart:":"positive", ":kissing_closed_eyes:":"positive", 
    ":flushed:":"positive", ":relieved":"positive", ":satisfied:":"positive", ":grin:":"positive", ":wink:":"positive",
    ":stuck_out_tongue_winking_eye:":"neutral", ":stuck_out_tongue_closed_eyes:":"negative", ":grinning:":"positive",
    ":kissing:":"positive", ":kissing_smiling_eyes:":"positive", ":stuck_out_tongue:":"positive", ":sleeping:":"negative",
    ":worried:":"negative", ":frowning:":"negative", ":anguished:":"negative", ":open_mouth:":"neutral", 
    ":grimacing:":"negative", ":confused:":"neutral", ":hushed:":"neutral", ":expressionless:":"negative", 
    ":unamused:":"negative", ":sweat_smile:":"positive", ":sweat:":"negative", ":disappointed_relieved:":"negative",
    ":disappointed:":"negative", ":sob:":"negative", ":joy:":"positive", ":smiling_imp:":"positive", ":heart:":"positive",
    ":cloud_with_rain:":"positive", ":loudly crying face:":"positive", ":thinking_face:":"neutral", 
    ":smiling_face_with_halo:":"positive", ":face_with_rolling_eyes:":"negative", ":revolving_hearts:":"positive",
    ":relieved_face:":"positive", ":face_with_tears_of_joy:":"positive", ":heart_with_arrow:":"positive",
    ":sparkling_heart:":"positive", ":heart_with_ribbon:":"positive", ":pleading_face:":"positive",
    ":sparkles:":"positive", ":purple_heart:":"positive", ":unicorn:":"positive", ":broken_heart:":"positive",
    ":pensive_face:":"neutral", ":smirking face:":"positive", ":confused_face:":"neutral",
    ":smiling_face_with_hearts:":"positive", ":sleepy:":"negative",":blue_heart:":"positive",":fire:":"positive",
    ":hankey:":"negative", 
}

# Keep track of sentiment value
posValue = 0
negValue = 0
neutralValue = 0

# Keep track of cleaned tweets
cleanedTweets = []

# %%
for column_name in choni_csv:
    print(column_name)
# Out:
# tweets
# quote_status
# language
# favorite_count
# retweet_count
# time
# id
# rating
# processed_text
# cleaned_tweets

# %%
for column_name, item in choni_csv.iteritems():
    if column_name == 'tweets':
        print(item)
        print('------')
# Out:
# 0       Bughead was never meant to be a main couple on...
# 1                        (especially on bughead day) HELP
# 2       her little smile after it END OF DISCUSSION BU...
# 3       RT @lovemesometopaz: if you still think bughea...
# 4       RT @BugheadGif: four years ago today, jughead ...
#                               ...
# 5027                  @BarchieUpdates Noo, bughead #4ever
# 5028    meu pai me mandando gif de bughead KKKKKKKKVOU...
# 5029    @barchiecanons5 @rytbone @Barchiedaily He may ...
# 5030    @ChaosPper @NessaJ785 Yeah, IMO bughead is tox...
# 5031    @Lauraisback25 I don't think they will, and ho...
# Name: tweets, Length: 5032, dtype: object
# ------

# %%
def normalize_Text(text):
    print('---[START]text before modifying:---')
    print(text)
    textModified = text.lower()
    textModified = emoji.demojize(textModified)
    print('---Emoji modified text---')
    print(textModified)
    textModified = re.sub("@[A-Za-z0-9]+","", textModified) #Remove @ sign
    textModified = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", textModified) #Remove http links
    textModified = textModified.replace("#", "").replace("_", " ") #Remove hashtag sign but keep the text
    print("---Removed Unnecesary pieces---")
    print(textModified)
    print('---[END]---')
    return textModified
    
def sentiment_by_rules(text):
    # First clean the text
    global posValue;
    global negValue;
    global neutralValue;
    cleanedText = normalize_Text(text)
    # calculate emotes before splitting keys as its hard to do a key comparison with string split
    for key in emoteToken:
        if key in text:
            if emoteToken[key] == 'positive':
                posValue = posValue + 1
            elif emoteToken[key] == 'negative':
                negValue = negValue + 1
            else:
                neutralValue = neutralValue + 1
    cleanedTweets.append(cleanedText)
    # split string so its easier to do token comparison
    textSplit = cleanedText.split()
    print("Text Split:")
    print(textSplit)
    for x in textSplit:
        if ':' in x :
            #if theres a colon then that means it has an emote so ignore adding double pos or neg or neu values
            pass
        elif any(ele for ele in posTokens if(ele in x)):
            posValue = posValue + 1
        elif any(ele for ele in negTokens if(ele in x)):
            negValue = negValue + 1
        else :
            neutralValue = neutralValue + 1
    
    # If neutral value is greater than 3 times the sum of posValue and negValue than have a consistant normalizer of div 3
    # so if pos and neg are 2 each but neutral is 12 or more divide it by 3 to make values a little more consistent. Ignore
    # this if theres no posValue or negValue as that should be a neutral statement then
    if posValue != 0 and negValue != 0 and neutralValue > ((posValue + negValue) * 3):
        neutralValue = neutralValue / 3
    
    total = posValue + negValue + neutralValue
    
    if total != 0:
        sentimentPos.append(float(posValue / total))
        sentimentNeg.append(float(negValue / total))
        sentimentNeu.append(float(neutralValue / total))
    else:
        sentimentPos.append(0)
        sentimentNeg.append(0)
        sentimentNeu.append(0)
    
    posValue = 0
    negValue = 0
    neutralValue = 0

# %%
for ind in choni_csv.index:
    sentiment_by_rules(choni_csv['tweets'][ind])
# Out:
# ---[START]text before modifying:---
# Bughead was never meant to be a main couple on the show.”
#
# Again, yes they literally were. RAS had Bughead in mind before the show even started, but BAs don’t even bother doing their research before saying anything. They always embarrass themselves. https://t.co/u8XIDocU5q
# ---Emoji modified text---
# bughead was never meant to be a main couple on the show.”
#
# again, yes they literally were. ras had bughead in mind before the show even started, but bas don’t even bother doing their research before saying anything. they always embarrass themselves. https://t.co/u8xidocu5q
# ---Removed Unnecesary pieces---
# bughead was never meant to be a main couple on the show.”
#
# again, yes they literally were. ras had bughead in mind before the show even started, but bas don’t even bother doing their research before saying anything. they always embarrass themselves.
# ---[END]---
# Text Split:
# ['bughead', 'was', 'never', 'meant', 'to', 'be', 'a', 'main', 'couple', 'on', 'the', 'show.”', 'again,', 'yes', 'they', 'literally', 'were.', 'ras', 'had', 'bughead', 'in', 'mind', 'before', 'the', 'show', 'even', 'started,', 'but', 'bas', 'don’t', 'even', 'bother', 'doing', 'their', 'research', 'before', 'saying', 'anything.', 'they', 'always', 'embarrass', 'themselves.']
# ---[START]text before modifying:---
# (especially on bughead day) HELP
# ---Emoji modified text---
# (especially on bughead day) help
# ---Removed Unnecesary pieces---
# (especially on bughead day) help
# ---[END]---
# Text Split:
# ['(especially', 'on', 'bughead', 'day)', 'help']
# ---[START]text before modifying:---
# her little smile after it END OF DISCUSSION BUGHEAD ENDGAME https://t.co/Iol4Gx4Wts
# ---Emoji modified text---
# her little smile after it end of discussion bughead endgame https://t.co/iol4gx4wts
# ---Removed Unnecesary pieces---
# her little smile after it end of discussion bughead endgame
# ---[END]---
# Text Split:
# ['her', 'little', 'smile', 'after', 'it', 'end', 'of', 'discussion', 'bughead', 'endgame']
# ---[START]text before modifying:---
# RT @lovemesometopaz: if you still think bughead was always supposed to be a main couple and take over the show and lili and cole’s relation…
# ---Emoji modified text---
# rt @lovemesometopaz: if you still think bughead was always supposed to be a main couple and take over the show and lili and cole’s relation…
# ---Removed Unnecesary pieces---
# rt : if you still think bughead was always supposed to be a main couple and take over the show and lili and cole’s relation…
# ---[END]---
# Text Split:
# ['rt', ':', 'if', 'you', 'still', 'think', 'bughead', 'was', 'always', 'supposed', 'to', 'be', 'a', 'main', 'couple', 'and', 'take', 'over', 'the', 'show', 'and', 'lili', 'and', 'cole’s', 'relation…']
# ---[START]text before modifying:---
# RT @BugheadGif: four years ago today, jughead jones climbed through betty cooper's window and kissed her for the first time.
#
# happy #bughea…
# ---Emoji modified text---
# rt @bugheadgif: four years ago today, jughead jones climbed through betty cooper's window and kissed her for the first time.
#
# happy #bughea…
# ---Removed Unnecesary pieces---
# rt : four years ago today, jughead jones climbed through betty cooper's window and kissed her for the first time.
#
# happy bughea…
# ---[END]---
# Text Split:
# ['rt', ':', 'four', 'years', 'ago', 'today,', 'jughead', 'jones', 'climbed', 'through', 'betty', "cooper's", 'window', 'and', 'kissed', 'her', 'for', 'the', 'first', 'time.', 'happy', 'bughea…']
# ---[START]text before modifying:---
# RT @mitchelsdemhawk: hating on bughead and varchie is not the serve yall think it is
# ---Emoji modified text---
# rt @mitchelsdemhawk: hating on bughead and varchie is not the serve yall think it is
# ---Removed Unnecesary pieces---
# rt : hating on bughead and varchie is not the serve yall think it is
# ---[END]---
# Text Split:
# ['rt', ':', 'hating', 'on', 'bughead', 'and', 'varchie', 'is', 'not', 'the', 'serve', 'yall', 'think', 'it', 'is']
# ---[START]text before modifying:---
# RT @bugheadaIe: saying bughead was never supposed to be a main couple (especially on bughead day) won’t change 5 seasons of canon and just…
# ---Emoji modified text---
# rt @bugheadaie: saying bughead was never supposed to be a main couple (especially on bughead day) won’t change 5 seasons of canon and just…
# ---Removed Unnecesary pieces---
# rt : saying bughead was never supposed to be a main couple (especially on bughead day) won’t change 5 seasons of canon and just…
# ---[END]---
# Text Split:
# ['rt', ':', 'saying', 'bughead', 'was', 'never', 'supposed', 'to', 'be', 'a', 'main', 'couple', '(especially', 'on', 'bughead', 'day)', 'won’t', 'change', '5', 'seasons', 'of', 'canon', 'and', 'just…']
# ---[START]text before modifying:---
# RAS is a huge Bughead, he has taste.
# ---Emoji modified text---
# ras is a huge bughead, he has taste.
# ---Removed Unnecesary pieces---
# ras is a huge bughead, he has taste.
# ---[END]---
# Text Split:
# ['ras', 'is', 'a', 'huge', 'bughead,', 'he', 'has', 'taste.']
# ---[START]text before modifying:---
# RT @BugheadUpdates: 4 years ago today, Jughead climbed up to Betty's window and they had their first kiss.
#
# Happy #Bughead day! #Riverdale…
# ---Emoji modified text---
# rt @bugheadupdates: 4 years ago today, jughead climbed up to betty's window and they had their first kiss.
#
# happy #bughead day! #riverdale…
# ---Removed Unnecesary pieces---
# rt : 4 years ago today, jughead climbed up to betty's window and they had their first kiss.
#
# happy bughead day! riverdale…
# ---[END]---
# Text Split:
# ['rt', ':', '4', 'years', 'ago', 'today,', 'jughead', 'climbed', 'up', 'to', "betty's", 'window', 'and', 'they', 'had', 'their', 'first', 'kiss.', 'happy', 'bughead', 'day!', 'riverdale…']
# ---[START]text before modifying:---
# RT @BamSmackPow: On this day we celebrate one of Riverdale’s endgame couples. 🥰
#
# Happy Bughead Day! 😘 https://t.co/WG2Ym8X4Ey
# ---Emoji modified text---
# rt @bamsmackpow: on this day we celebrate one of riverdale’s endgame couples. :smiling_face_with_hearts:
#
# happy bughead day! :face_blowing_a_kiss: https://t.co/wg2ym8x4ey
# ---Removed Unnecesary pieces---
# rt : on this day we celebrate one of riverdale’s endgame couples. :smiling face with hearts:
#
# happy bughead day! :face blowing a kiss:
# ---[END]---
# Text Split:
# ['rt', ':', 'on', 'this', 'day', 'we', 'celebrate', 'one', 'of', 'riverdale’s', 'endgame', 'couples.', ':smiling', 'face', 'with', 'hearts:', 'happy', 'bughead', 'day!', ':face', 'blowing', 'a', 'kiss:']
# ---[START]text before modifying:---
# @CW_Riverdale  #Bughead are so good man ! @lilireinhart  &amp; @colesprouse  chemistry is excellent and natural! #BUGHEADENDGAME https://t.co/lF5VPSHmBK
# ---Emoji modified text---
# @cw_riverdale  #bughead are so good man ! @lilireinhart  &amp; @colesprouse  chemistry is excellent and natural! #bugheadendgame https://t.co/lf5vpshmbk
# ---Removed Unnecesary pieces---
#  riverdale  bughead are so good man !   &amp;   chemistry is excellent and natural! bugheadendgame
# ---[END]---
# Text Split:
# ['riverdale', 'bughead', 'are', 'so', 'good', 'man', '!', '&amp;', 'chemistry', 'is', 'excellent', 'and', 'natural!', 'bugheadendgame']
# ---[START]text before modifying:---
# RT @BudhooJohn: @MTVAwards It's their day but anything with bughead, varchie and choni.#Riverdale https://t.co/bZt3AjOcye
# ---Emoji modified text---
# rt @budhoojohn: @mtvawards it's their day but anything with bughead, varchie and choni.#riverdale https://t.co/bzt3ajocye
# ---Removed Unnecesary pieces---
# rt :  it's their day but anything with bughead, varchie and choni.riverdale
# ---[END]---
# Text Split:
# ['rt', ':', "it's", 'their', 'day', 'but', 'anything', 'with', 'bughead,', 'varchie', 'and', 'choni.riverdale']
# ---[START]text before modifying:---
# @BamSmackPow OMG happy bughead day for you too bestie
# ---Emoji modified text---
# @bamsmackpow omg happy bughead day for you too bestie
# ---Removed Unnecesary pieces---
#  omg happy bughead day for you too bestie
# ---[END]---
# Text Split:
# ['omg', 'happy', 'bughead', 'day', 'for', 'you', 'too', 'bestie']
# ---[START]text before modifying:---
# RT @ColeSprouseidol: 4 years ago wao 😍❤️ #Bughead #Riverdale https://t.co/y6bvRMtdKN
# ---Emoji modified text---
# rt @colesprouseidol: 4 years ago wao :smiling_face_with_heart-eyes::red_heart: #bughead #riverdale https://t.co/y6bvrmtdkn
# ---Removed Unnecesary pieces---
# rt : 4 years ago wao :smiling face with heart-eyes::red heart: bughead riverdale
# ---[END]---
# Text Split:
# ['rt', ':', '4', 'years', 'ago', 'wao', ':smiling', 'face', 'with', 'heart-eyes::red', 'heart:', 'bughead', 'riverdale']
# ---[START]text before modifying:---
# RT @httpreinhart: Happy #Bughead day https://t.co/aX55xYjZ8P
# ---Emoji modified text---
# rt @httpreinhart: happy #bughead day https://t.co/ax55xyjz8p
# ---Removed Unnecesary pieces---
# rt : happy bughead day
# ---[END]---
# Text Split:
# ['rt', ':', 'happy', 'bughead', 'day']
# ---[START]text before modifying:---
# RT @selinascavone: in my bughead depression right now😄
# #Riverdale #bughead https://t.co/2gluuL1TwL
# ---Emoji modified text---
# rt @selinascavone: in my bughead depression right now:grinning_face_with_smiling_eyes:
# #riverdale #bughead https://t.co/2gluul1twl
# ---Removed Unnecesary pieces---
# rt : in my bughead depression right now:grinning face with smiling eyes:
# riverdale bughead
# ---[END]---
# Text Split:
# ['rt', ':', 'in', 'my', 'bughead', 'depression', 'right', 'now:grinning', 'face', 'with', 'smiling', 'eyes:', 'riverdale', 'bughead']
# ---[START]text before modifying:---
# if bughead not endgame, why roberto? https://t.co/ctlK8Qv9Zh
# ---Emoji modified text---
# if bughead not endgame, why roberto? https://t.co/ctlk8qv9zh
# ---Removed Unnecesary pieces---
# if bughead not endgame, why roberto?
# ---[END]---
# Text Split:
# ['if', 'bughead', 'not', 'endgame,', 'why', 'roberto?']
# ---[START]text before modifying:---
# RT @Southside_Jug: “I’m here for you. Always.” #Riverdale #bughead https://t.co/v0maq7rdGN
# ---Emoji modified text---
# rt @southside_jug: “i’m here for you. always.” #riverdale #bughead https://t.co/v0maq7rdgn
# ---Removed Unnecesary pieces---
# rt  jug: “i’m here for you. always.” riverdale bughead
# ---[END]---
# Text Split:
# ['rt', 'jug:', '“i’m', 'here', 'for', 'you.', 'always.”', 'riverdale', 'bughead']
# ---[START]text before modifying:---
# RT @reinhartshines: 4 years ago today #bughead was born
# #riverdale https://t.co/72hP2uizIX
# ---Emoji modified text---
# rt @reinhartshines: 4 years ago today #bughead was born
# #riverdale https://t.co/72hp2uizix
# ---Removed Unnecesary pieces---
# rt : 4 years ago today bughead was born
# riverdale
# ---[END]---
# Text Split:
# ['rt', ':', '4', 'years', 'ago', 'today', 'bughead', 'was', 'born', 'riverdale']
# ---[START]text before modifying:---
# RT @Southside_Jug: Remembering there is no new episode tomorrow night #Riverdale #bughead https://t.co/cf0sfFrph1
# ---Emoji modified text---
# rt @southside_jug: remembering there is no new episode tomorrow night #riverdale #bughead https://t.co/cf0sffrph1
# ---Removed Unnecesary pieces---
# rt  jug: remembering there is no new episode tomorrow night riverdale bughead
# ---[END]---
# Text Split:
# ['rt', 'jug:', 'remembering', 'there', 'is', 'no', 'new', 'episode', 'tomorrow', 'night', 'riverdale', 'bughead']
# ---[START]text before modifying:---
# RT @frutifantastiko: Not again #bughead #Riverdale https://t.co/brT6uKo9OY
# ---Emoji modified text---
# rt @frutifantastiko: not again #bughead #riverdale https://t.co/brt6uko9oy
# ---Removed Unnecesary pieces---
# rt : not again bughead riverdale
# ---[END]---
# Text Split:
# ['rt', ':', 'not', 'again', 'bughead', 'riverdale']
# ---[START]text before modifying:---
# RT @Barchies3: #Barchie #Riverdale
#
# I don't understand how Bughead stans' brains work https://t.co/TM0dRn6uAu
# ---Emoji modified text---
# rt @barchies3: #barchie #riverdale
#
# i don't understand how bughead stans' brains work https://t.co/tm0drn6uau
# ---Removed Unnecesary pieces---
# rt : barchie riverdale
#
# i don't understand how bughead stans' brains work
# ---[END]---
# Text Split:
# ['rt', ':', 'barchie', 'riverdale', 'i', "don't", 'understand', 'how', 'bughead', "stans'", 'brains', 'work']
# ---[START]text before modifying:---
# RT @JugBetts: When the sequel wins an Emmy &gt;&gt;&gt;&gt;&gt;
# #Riverdale #Bughead
# ---Emoji modified text---
# rt @jugbetts: when the sequel wins an emmy &gt;&gt;&gt;&gt;&gt;
# #riverdale #bughead
# ---Removed Unnecesary pieces---
# rt : when the sequel wins an emmy &gt;&gt;&gt;&gt;&gt;
# riverdale bughead
# ---[END]---
# Text Split:
# ['rt', ':', 'when', 'the', 'sequel', 'wins', 'an', 'emmy', '&gt;&gt;&gt;&gt;&gt;', 'riverdale', 'bughead']
# ---[START]text before modifying:---
# RT @claire39458517: Now has she ever looked at Archie that way? I don’t think so💁🏽‍♀️. After 7 years and still her heart knows that she bel…
# ---Emoji modified text---
# rt @claire39458517: now has she ever looked at archie that way? i don’t think so:woman_tipping_hand_medium_skin_tone:. after 7 years and still her heart knows that she bel…
# ---Removed Unnecesary pieces---
# rt : now has she ever looked at archie that way? i don’t think so:woman tipping hand medium skin tone:. after 7 years and still her heart knows that she bel…
# ---[END]---
# Text Split:
# ['rt', ':', 'now', 'has', 'she', 'ever', 'looked', 'at', 'archie', 'that', 'way?', 'i', 'don’t', 'think', 'so:woman', 'tipping', 'hand', 'medium', 'skin', 'tone:.', 'after', '7', 'years', 'and', 'still', 'her', 'heart', 'knows', 'that', 'she', 'bel…']
# ---[START]text before modifying:---
# RT @Southside_Jug: Betty, return to Jughead. You know your heart belongs to him only. #Riverdale #bughead https://t.co/gdmoT0OtFW
# ---Emoji modified text---
# rt @southside_jug: betty, return to jughead. you know your heart belongs to him only. #riverdale #bughead https://t.co/gdmot0otfw
# ---Removed Unnecesary pieces---
# rt  jug: betty, return to jughead. you know your heart belongs to him only. riverdale bughead
# ---[END]---
# Text Split:
# ['rt', 'jug:', 'betty,', 'return', 'to', 'jughead.', 'you', 'know', 'your', 'heart', 'belongs', 'to', 'him', 'only.', 'riverdale', 'bughead']
# ---[START]text before modifying:---
# RT @reinhartsdreams: it was only 4 years ago today that jughead climbed into betty’s window, called her juliet, and kissed her for the firs…
# ---Emoji modified text---
# rt @reinhartsdreams: it was only 4 years ago today that jughead climbed into betty’s window, called her juliet, and kissed her for the firs…
# ---Removed Unnecesary pieces---
# rt : it was only 4 years ago today that jughead climbed into betty’s window, called her juliet, and kissed her for the firs…
# ---[END]---
# Text Split:
# ['rt', ':', 'it', 'was', 'only', '4', 'years', 'ago', 'today', 'that', 'jughead', 'climbed', 'into', 'betty’s', 'window,', 'called', 'her', 'juliet,', 'and', 'kissed', 'her', 'for', 'the', 'firs…']
# ---[START]text before modifying:---
# RT @Itsjubiz: Now has she ever looked at Archie that way? I don’t think so. After 7 years and still her heart knows that she belongs to him…
# ---Emoji modified text---
# rt @itsjubiz: now has she ever looked at archie that way? i don’t think so. after 7 years and still her heart knows that she belongs to him…
# ---Removed Unnecesary pieces---
# rt : now has she ever looked at archie that way? i don’t think so. after 7 years and still her heart knows that she belongs to him…
# ---[END]---
# Text Split:
# ['rt', ':', 'now', 'has', 'she', 'ever', 'looked', 'at', 'archie', 'that', 'way?', 'i', 'don’t', 'think', 'so.', 'after', '7', 'years', 'and', 'still', 'her', 'heart', 'knows', 'that', 'she', 'belongs', 'to', 'him…']
# ---[START]text before modifying:---
# @colesxhart Thanks so much bestie Happy Bughead Day! 🥰
# ---Emoji modified text---
# @colesxhart thanks so much bestie happy bughead day! :smiling_face_with_hearts:
# ---Removed Unnecesary pieces---
#  thanks so much bestie happy bughead day! :smiling face with hearts:
# ---[END]---
# Text Split:
# ['thanks', 'so', 'much', 'bestie', 'happy', 'bughead', 'day!', ':smiling', 'face', 'with', 'hearts:']
# ---[START]text before modifying:---
# RT @SoldiersTom: Lili and Cole were very close to each other, just like Bob and Eliza. I don't know how the Black Cat got between you... Bu…
# ---Emoji modified text---
# rt @soldierstom: lili and cole were very close to each other, just like bob and eliza. i don't know how the black cat got between you... bu…
# ---Removed Unnecesary pieces---
# rt : lili and cole were very close to each other, just like bob and eliza. i don't know how the black cat got between you... bu…
# ---[END]---
# Text Split:
# ['rt', ':', 'lili', 'and', 'cole', 'were', 'very', 'close', 'to', 'each', 'other,', 'just', 'like', 'bob', 'and', 'eliza.', 'i', "don't", 'know', 'how', 'the', 'black', 'cat', 'got', 'between', 'you...', 'bu…']
# ---[START]text before modifying:---
# if i see one bughead shipper saying that barchie has no chemistry and that it’s a whole downgrade of bughead i will prosecute your ass 😗
# ---Emoji modified text---
# if i see one bughead shipper saying that barchie has no chemistry and that it’s a whole downgrade of bughead i will prosecute your ass :kissing_face:
# ---Removed Unnecesary pieces---
# if i see one bughead shipper saying that barchie has no chemistry and that it’s a whole downgrade of bughead i will prosecute your ass :kissing face:
# ---[END]---
# Text Split:
# ['if', 'i', 'see', 'one', 'bughead', 'shipper', 'saying', 'that', 'barchie', 'has', 'no', 'chemistry', 'and', 'that', 'it’s', 'a', 'whole', 'downgrade', 'of', 'bughead', 'i', 'will', 'prosecute', 'your', 'ass', ':kissing', 'face:']
# ---[START]text before modifying:---
# RT @Kiimora2: I was just a bughead LAST WEEK but I don’t know the more I interact with barchie shippers and the more lili posts about barch…
# ---Emoji modified text---
# rt @kiimora2: i was just a bughead last week but i don’t know the more i interact with barchie shippers and the more lili posts about barch…
# ---Removed Unnecesary pieces---
# rt : i was just a bughead last week but i don’t know the more i interact with barchie shippers and the more lili posts about barch…
# ---[END]---
# Text Split:
# ['rt', ':', 'i', 'was', 'just', 'a', 'bughead', 'last', 'week', 'but', 'i', 'don’t', 'know', 'the', 'more', 'i', 'interact', 'with', 'barchie', 'shippers', 'and', 'the', 'more', 'lili', 'posts', 'about', 'barch…']
# ---[START]text before modifying:---
# RT @willowiscold: I'm 26, I shouldn't care that barchie are together now, but it does, it bothers me so much! Bring #bughead back! #riverda…
# ---Emoji modified text---
# rt @willowiscold: i'm 26, i shouldn't care that barchie are together now, but it does, it bothers me so much! bring #bughead back! #riverda…
# ---Removed Unnecesary pieces---
# rt : i'm 26, i shouldn't care that barchie are together now, but it does, it bothers me so much! bring bughead back! riverda…
# ---[END]---
# Text Split:
# ['rt', ':', "i'm", '26,', 'i', "shouldn't", 'care', 'that', 'barchie', 'are', 'together', 'now,', 'but', 'it', 'does,', 'it', 'bothers', 'me', 'so', 'much!', 'bring', 'bughead', 'back!', 'riverda…']
# ---[START]text before modifying:---
# RT @RiverdaleDark: Happy #Bughead Day 🥰 https://t.co/fZbi35WHBM
# ---Emoji modified text---
# rt @riverdaledark: happy #bughead day :smiling_face_with_hearts: https://t.co/fzbi35whbm
# ---Removed Unnecesary pieces---
# rt : happy bughead day :smiling face with hearts:
# ---[END]---
# Text Split:
# ['rt', ':', 'happy', 'bughead', 'day', ':smiling', 'face', 'with', 'hearts:']
# ---[START]text before modifying:---
# RT @Fatimiuz2: Today friends my favorite couple gave their first kiss and I have been happy (until chapter 4.17 of there until now they onl…
# ---Emoji modified text---
# rt @fatimiuz2: today friends my favorite couple gave their first kiss and i have been happy (until chapter 4.17 of there until now they onl…
# ---Removed Unnecesary pieces---
# rt : today friends my favorite couple gave their first kiss and i have been happy (until chapter 4.17 of there until now they onl…
# ---[END]---
# Text Split:
# ['rt', ':', 'today', 'friends', 'my', 'favorite', 'couple', 'gave', 'their', 'first', 'kiss', 'and', 'i', 'have', 'been', 'happy', '(until', 'chapter', '4.17', 'of', 'there', 'until', 'now', 'they', 'onl…']
# ---[START]text before modifying:---
# RT @edegelene: Bughead parin, even though in that scene was Barchie🥺#Riverdale #Chapter82 https://t.co/fvrwjkGnjd
# ---Emoji modified text---
# rt @edegelene: bughead parin, even though in that scene was barchie:pleading_face:#riverdale #chapter82 https://t.co/fvrwjkgnjd
# ---Removed Unnecesary pieces---
# rt : bughead parin, even though in that scene was barchie:pleading face:riverdale chapter82
# ---[END]---
# Text Split:
# ['rt', ':', 'bughead', 'parin,', 'even', 'though', 'in', 'that', 'scene', 'was', 'barchie:pleading', 'face:riverdale', 'chapter82']
# ---[START]text before modifying:---
# RT @bugheadconfess_: Happy Bughead’s day https://t.co/Za4xEBdIOm
# ---Emoji modified text---
# rt @bugheadconfess_: happy bughead’s day https://t.co/za4xebdiom
# ---Removed Unnecesary pieces---
# rt  : happy bughead’s day
# ---[END]---
# Text Split:
# ['rt', ':', 'happy', 'bughead’s', 'day']
# ---[START]text before modifying:---
# RT @bugheadspov: 4 years ago today, jughead climbed through betty’s window, called her juliet, calmed her nerves, AND kissed her for the fi…
# ---Emoji modified text---
# rt @bugheadspov: 4 years ago today, jughead climbed through betty’s window, called her juliet, calmed her nerves, and kissed her for the fi…
# ---Removed Unnecesary pieces---
# rt : 4 years ago today, jughead climbed through betty’s window, called her juliet, calmed her nerves, and kissed her for the fi…
# ---[END]---
# Text Split:
# ['rt', ':', '4', 'years', 'ago', 'today,', 'jughead', 'climbed', 'through', 'betty’s', 'window,', 'called', 'her', 'juliet,', 'calmed', 'her', 'nerves,', 'and', 'kissed', 'her', 'for', 'the', 'fi…']
# ---[START]text before modifying:---
# RT @catacaceress: happy anniversary bbys
# #riverdale #bughead https://t.co/PJyhVel223
# ---Emoji modified text---
# rt @catacaceress: happy anniversary bbys
# #riverdale #bughead https://t.co/pjyhvel223
# ---Removed Unnecesary pieces---
# rt : happy anniversary bbys
# riverdale bughead
# ---[END]---
# Text Split:
# ['rt', ':', 'happy', 'anniversary', 'bbys', 'riverdale', 'bughead']
# ---[START]text before modifying:---
# @your_crazy_4you @chon1_bughead @lemon_buzz @DailyMailCeleb The thanksgiving pic
# ---Emoji modified text---
# @your_crazy_4you @chon1_bughead @lemon_buzz @dailymailceleb the thanksgiving pic
# ---Removed Unnecesary pieces---
#  crazy 4you  bughead  buzz  the thanksgiving pic
# ---[END]---
# Text Split:
# ['crazy', '4you', 'bughead', 'buzz', 'the', 'thanksgiving', 'pic']
# ---[START]text before modifying:---
# bughead day the best day
# ---Emoji modified text---
# bughead day the best day
# ---Removed Unnecesary pieces---
# bughead day the best day
# ---[END]---
# Text Split:
# ['bughead', 'day', 'the', 'best', 'day']
# ---[START]text before modifying:---
# Bughead 2.0 https://t.co/zw9DLte3A8
# ---Emoji modified text---
# bughead 2.0 https://t.co/zw9dlte3a8
# ---Removed Unnecesary pieces---
# bughead 2.0
# ---[END]---
# Text Split:
# ['bughead', '2.0']
# ---[START]text before modifying:---
# @chon1_bughead @lemon_buzz @pursuit23 @DailyMailCeleb I'm sorry but I don't see lili anywhere
# ---Emoji modified text---
# @chon1_bughead @lemon_buzz @pursuit23 @dailymailceleb i'm sorry but i don't see lili anywhere
# ---Removed Unnecesary pieces---
#  bughead  buzz   i'm sorry but i don't see lili anywhere
# ---[END]---
# Text Split:
# ['bughead', 'buzz', "i'm", 'sorry', 'but', 'i', "don't", 'see', 'lili', 'anywhere']
# ---[START]text before modifying:---
# RT @naleybugheads: happy bughead day! #Riverdale https://t.co/dJRlY23r8S
# ---Emoji modified text---
# rt @naleybugheads: happy bughead day! #riverdale https://t.co/djrly23r8s
# ---Removed Unnecesary pieces---
# rt : happy bughead day! riverdale
# ---[END]---
# Text Split:
# ['rt', ':', 'happy', 'bughead', 'day!', 'riverdale']
# ---[START]text before modifying:---
# @MTVAwards Bughead ❤️ https://t.co/e79TZGLKC3
# ---Emoji modified text---
# @mtvawards bughead :red_heart: https://t.co/e79tzglkc3
# ---Removed Unnecesary pieces---
#  bughead :red heart:
# ---[END]---
# Text Split:
# ['bughead', ':red', 'heart:']
# ---[START]text before modifying:---
# RT @rayygraphy: Hi Bugheads,
#
# Jughead kissed Betty for the first time four years ago today.
#
# Happy #Bughead day, everyone!❤️
#
# #Riverdale
# ---Emoji modified text---
# rt @rayygraphy: hi bugheads,
#
# jughead kissed betty for the first time four years ago today.
#
# happy #bughead day, everyone!:red_heart:
#
# #riverdale
# ---Removed Unnecesary pieces---
# rt : hi bugheads,
#
# jughead kissed betty for the first time four years ago today.
#
# happy bughead day, everyone!:red heart:
#
# riverdale
# ---[END]---
# Text Split:
# ['rt', ':', 'hi', 'bugheads,', 'jughead', 'kissed', 'betty', 'for', 'the', 'first', 'time', 'four', 'years', 'ago', 'today.', 'happy', 'bughead', 'day,', 'everyone!:red', 'heart:', 'riverdale']
# ---[START]text before modifying:---
# sometimes I forget how weird  bughead is as a ship name... I’m not dissing the actual ship (!!!) it’s just the name makes me laugh. bug...head. 🐜
# ---Emoji modified text---
# sometimes i forget how weird  bughead is as a ship name... i’m not dissing the actual ship (!!!) it’s just the name makes me laugh. bug...head. :ant:
# ---Removed Unnecesary pieces---
# sometimes i forget how weird  bughead is as a ship name... i’m not dissing the actual ship (!!!) it’s just the name makes me laugh. bug...head. :ant:
# ---[END]---
# Text Split:
# ['sometimes', 'i', 'forget', 'how', 'weird', 'bughead', 'is', 'as', 'a', 'ship', 'name...', 'i’m', 'not', 'dissing', 'the', 'actual', 'ship', '(!!!)', 'it’s', 'just', 'the', 'name', 'makes', 'me', 'laugh.', 'bug...head.', ':ant:']
# ---[START]text before modifying:---
# @spreindestch bughead
# ---Emoji modified text---
# @spreindestch bughead
# ---Removed Unnecesary pieces---
#  bughead
# ---[END]---
# Text Split:
# ['bughead']
# ---[START]text before modifying:---
# RT @barchiedestiny: Reasons why Choni and Barchie are better than Varchie and Bughead.
#
# Bughead= Cute, Understanding
# Varchie= Hot , Passion…
# ---Emoji modified text---
# rt @barchiedestiny: reasons why choni and barchie are better than varchie and bughead.
#
# bughead= cute, understanding
# varchie= hot , passion…
# ---Removed Unnecesary pieces---
# rt : reasons why choni and barchie are better than varchie and bughead.
#
# bughead= cute, understanding
# varchie= hot , passion…
# ---[END]---
# Text Split:
# ['rt', ':', 'reasons', 'why', 'choni', 'and', 'barchie', 'are', 'better', 'than', 'varchie', 'and', 'bughead.', 'bughead=', 'cute,', 'understanding', 'varchie=', 'hot', ',', 'passion…']
# ---[START]text before modifying:---
# @spreindestch bughead 🤲🏻
# ---Emoji modified text---
# @spreindestch bughead :palms_up_together_light_skin_tone:
# ---Removed Unnecesary pieces---
#  bughead :palms up together light skin tone:
# ---[END]---
# Text Split:
# ['bughead', ':palms', 'up', 'together', 'light', 'skin', 'tone:']
# ---[START]text before modifying:---
# RT @reinhartsdivine: we needed that to be continue moment, but oh well, happy 4 years of their first kiss 🥺👌🏻 #bughead #riverdale https://t…
# ---Emoji modified text---
# rt @reinhartsdivine: we needed that to be continue moment, but oh well, happy 4 years of their first kiss :pleading_face::OK_hand_light_skin_tone: #bughead #riverdale https://t…
# ---Removed Unnecesary pieces---
# rt : we needed that to be continue moment, but oh well, happy 4 years of their first kiss :pleading face::OK hand light skin tone: bughead riverdale
# ---[END]---
# Text Split:
# ['rt', ':', 'we', 'needed', 'that', 'to', 'be', 'continue', 'moment,', 'but', 'oh', 'well,', 'happy', '4', 'years', 'of', 'their', 'first', 'kiss', ':pleading', 'face::OK', 'hand', 'light', 'skin', 'tone:', 'bughead', 'riverdale']
# ---[START]text before modifying:---
# RT @AlpacalypseA: some Romeo and Juliet for #Bughead  ’s anniversary 💙💛 https://t.co/ZaAk7nscgM
# ---Emoji modified text---
# rt @alpacalypsea: some romeo and juliet for #bughead  ’s anniversary :blue_heart::yellow_heart: https://t.co/zaak7nscgm
# ---Removed Unnecesary pieces---
# rt : some romeo and juliet for bughead  ’s anniversary :blue heart::yellow heart:
# ---[END]---
# Text Split:
# ['rt', ':', 'some', 'romeo', 'and', 'juliet', 'for', 'bughead', '’s', 'anniversary', ':blue', 'heart::yellow', 'heart:']
# ---[START]text before modifying:---
# RT @classyreinhart: 4 years ago today, jughead jones climbed up a ladder to betty cooper’s room and kissed her for the first time❤️ happy a…
# ---Emoji modified text---
# rt @classyreinhart: 4 years ago today, jughead jones climbed up a ladder to betty cooper’s room and kissed her for the first time:red_heart: happy a…
# ---Removed Unnecesary pieces---
# rt : 4 years ago today, jughead jones climbed up a ladder to betty cooper’s room and kissed her for the first time:red heart: happy a…
# ---[END]---
# Text Split:
# ['rt', ':', '4', 'years', 'ago', 'today,', 'jughead', 'jones', 'climbed', 'up', 'a', 'ladder', 'to', 'betty', 'cooper’s', 'room', 'and', 'kissed', 'her', 'for', 'the', 'first', 'time:red', 'heart:', 'happy', 'a…']
# ---[START]text before modifying:---
# RT @iywmlhart: happy #bughead day anniversary, everyone!
#
# #riverdale https://t.co/PJ07dmISIY
# ---Emoji modified text---
# rt @iywmlhart: happy #bughead day anniversary, everyone!
#
# #riverdale https://t.co/pj07dmisiy
# ---Removed Unnecesary pieces---
# rt : happy bughead day anniversary, everyone!
#
# riverdale
# ---[END]---
# Text Split:
# ['rt', ':', 'happy', 'bughead', 'day', 'anniversary,', 'everyone!', 'riverdale']
# ---[START]text before modifying:---
# RT @itsbarchiebxtch: *especially on bughead day* girl WHAT 😭 it’s not a national holiday 😭 https://t.co/vdOex8Q5wU
# ---Emoji modified text---
# rt @itsbarchiebxtch: *especially on bughead day* girl what :loudly_crying_face: it’s not a national holiday :loudly_crying_face: https://t.co/vdoex8q5wu
# ---Removed Unnecesary pieces---
# rt : *especially on bughead day* girl what :loudly crying face: it’s not a national holiday :loudly crying face:
# ---[END]---
# Text Split:
# ['rt', ':', '*especially', 'on', 'bughead', 'day*', 'girl', 'what', ':loudly', 'crying', 'face:', 'it’s', 'not', 'a', 'national', 'holiday', ':loudly', 'crying', 'face:']
# ---[START]text before modifying:---
# @blossomsvoid HOW DARE THEY RUIN OUr FAV SHIP (bughead) BY ACCUSING THE STRAIGHTEST MAN EVER OF BEING FRUITY 😔😑
# ---Emoji modified text---
# @blossomsvoid how dare they ruin our fav ship (bughead) by accusing the straightest man ever of being fruity :pensive_face::expressionless_face:
# ---Removed Unnecesary pieces---
#  how dare they ruin our fav ship (bughead) by accusing the straightest man ever of being fruity :pensive face::expressionless face:
# ---[END]---
# Text Split:
# ['how', 'dare', 'they', 'ruin', 'our', 'fav', 'ship', '(bughead)', 'by', 'accusing', 'the', 'straightest', 'man', 'ever', 'of', 'being', 'fruity', ':pensive', 'face::expressionless', 'face:']
# ---[START]text before modifying:---
# @spreindestch bughead🏡💘
# ---Emoji modified text---
# @spreindestch bughead:house_with_garden::heart_with_arrow:
# ---Removed Unnecesary pieces---
#  bughead:house with garden::heart with arrow:
# ---[END]---
# Text Split:
# ['bughead:house', 'with', 'garden::heart', 'with', 'arrow:']
# ---[START]text before modifying:---
# RT @reinhartsdivine: miss you.... :( #bughead https://t.co/0aHijaoNjU
# ---Emoji modified text---
# rt @reinhartsdivine: miss you.... :( #bughead https://t.co/0ahijaonju
# ---Removed Unnecesary pieces---
# rt : miss you.... :( bughead
# ---[END]---
# Text Split:
# ['rt', ':', 'miss', 'you....', ':(', 'bughead']
# ---[START]text before modifying:---
# *especially on bughead day* girl WHAT 😭 it’s not a national holiday 😭 https://t.co/vdOex8Q5wU
# ---Emoji modified text---
# *especially on bughead day* girl what :loudly_crying_face: it’s not a national holiday :loudly_crying_face: https://t.co/vdoex8q5wu
# ---Removed Unnecesary pieces---
# *especially on bughead day* girl what :loudly crying face: it’s not a national holiday :loudly crying face:
# ---[END]---
# Text Split:
# ['*especially', 'on', 'bughead', 'day*', 'girl', 'what', ':loudly', 'crying', 'face:', 'it’s', 'not', 'a', 'national', 'holiday', ':loudly', 'crying', 'face:']
# ---[START]text before modifying:---
# #Bughead is an endgame for me no matter what now :) https://t.co/hzcCy7YYQp
# ---Emoji modified text---
# #bughead is an endgame for me no matter what now :) https://t.co/hzccy7yyqp
# ---Removed Unnecesary pieces---
# bughead is an endgame for me no matter what now :)
# ---[END]---
# Text Split:
# ['bughead', 'is', 'an', 'endgame', 'for', 'me', 'no', 'matter', 'what', 'now', ':)']
# ---[START]text before modifying:---
# @barchanted They are lying as with 99% of their arguments of why Bughead is endgame
#
# The worst part is that all of their “proof” comes from pages like Bam Smack Pow
# ---Emoji modified text---
# @barchanted they are lying as with 99% of their arguments of why bughead is endgame
#
# the worst part is that all of their “proof” comes from pages like bam smack pow
# ---Removed Unnecesary pieces---
#  they are lying as with 99% of their arguments of why bughead is endgame
#
# the worst part is that all of their “proof” comes from pages like bam smack pow
# ---[END]---
# Text Split:
# ['they', 'are', 'lying', 'as', 'with', '99%', 'of', 'their', 'arguments', 'of', 'why', 'bughead', 'is', 'endgame', 'the', 'worst', 'part', 'is', 'that', 'all', 'of', 'their', '“proof”', 'comes', 'from', 'pages', 'like', 'bam', 'smack', 'pow']
# ---[START]text before modifying:---
# on my bughead breakdown again
#  https://t.co/bAAsX8gnoJ
# ---Emoji modified text---
# on my bughead breakdown again
#  https://t.co/baasx8gnoj
# ---Removed Unnecesary pieces---
# on my bughead breakdown again
#
# ---[END]---
# Text Split:
# ['on', 'my', 'bughead', 'breakdown', 'again']
# ---[START]text before modifying:---
# RT @lilireinhart: We had dialogue that was cut from this little montage-- Jughead made Betty laugh before finding the car-- thus this littl…
# ---Emoji modified text---
# rt @lilireinhart: we had dialogue that was cut from this little montage-- jughead made betty laugh before finding the car-- thus this littl…
# ---Removed Unnecesary pieces---
# rt : we had dialogue that was cut from this little montage-- jughead made betty laugh before finding the car-- thus this littl…
# ---[END]---
# Text Split:
# ['rt', ':', 'we', 'had', 'dialogue', 'that', 'was', 'cut', 'from', 'this', 'little', 'montage--', 'jughead', 'made', 'betty', 'laugh', 'before', 'finding', 'the', 'car--', 'thus', 'this', 'littl…']
# ---[START]text before modifying:---
# RT @juqheadjonez: eyes dilated 🥲 https://t.co/TRsHi8s1qc
# ---Emoji modified text---
# rt @juqheadjonez: eyes dilated :smiling_face_with_tear: https://t.co/trshi8s1qc
# ---Removed Unnecesary pieces---
# rt : eyes dilated :smiling face with tear:
# ---[END]---
# Text Split:
# ['rt', ':', 'eyes', 'dilated', ':smiling', 'face', 'with', 'tear:']
# ---[START]text before modifying:---
# RT @ForsythesCooper: Or... You could kiss your girlfriend https://t.co/MzrVcA9YGT
# ---Emoji modified text---
# rt @forsythescooper: or... you could kiss your girlfriend https://t.co/mzrvca9ygt
# ---Removed Unnecesary pieces---
# rt : or... you could kiss your girlfriend
# ---[END]---
# Text Split:
# ['rt', ':', 'or...', 'you', 'could', 'kiss', 'your', 'girlfriend']
# ---[START]text before modifying:---
# RT @fcrsythe: their love language being physical touch is my biggest win https://t.co/CjbcsPFVqk
# ---Emoji modified text---
# rt @fcrsythe: their love language being physical touch is my biggest win https://t.co/cjbcspfvqk
# ---Removed Unnecesary pieces---
# rt : their love language being physical touch is my biggest win
# ---[END]---
# Text Split:
# ['rt', ':', 'their', 'love', 'language', 'being', 'physical', 'touch', 'is', 'my', 'biggest', 'win']
# ---[START]text before modifying:---
# @paulineslove bughead shipper
# ---Emoji modified text---
# @paulineslove bughead shipper
# ---Removed Unnecesary pieces---
#  bughead shipper
# ---[END]---
# Text Split:
# ['bughead', 'shipper']
# ---[START]text before modifying:---
# RT @chonibIossom: can they release the 508 stills today i need content
# ---Emoji modified text---
# rt @chonibiossom: can they release the 508 stills today i need content
# ---Removed Unnecesary pieces---
# rt : can they release the 508 stills today i need content
# ---[END]---
# Text Split:
# ['rt', ':', 'can', 'they', 'release', 'the', '508', 'stills', 'today', 'i', 'need', 'content']
# ---[START]text before modifying:---
# RT @ForsythesCooper: They become each others safe place so easily https://t.co/Cm2V8Hdi7g
# ---Emoji modified text---
# rt @forsythescooper: they become each others safe place so easily https://t.co/cm2v8hdi7g
# ---Removed Unnecesary pieces---
# rt : they become each others safe place so easily
# ---[END]---
# Text Split:
# ['rt', ':', 'they', 'become', 'each', 'others', 'safe', 'place', 'so', 'easily']
# ---[START]text before modifying:---
# RT @naddumbass: my bughead heart couldn't take it anymore 💔
# ---Emoji modified text---
# rt @naddumbass: my bughead heart couldn't take it anymore :broken_heart:
# ---Removed Unnecesary pieces---
# rt : my bughead heart couldn't take it anymore :broken heart:
# ---[END]---
# Text Split:
# ['rt', ':', 'my', 'bughead', 'heart', "couldn't", 'take', 'it', 'anymore', ':broken', 'heart:']
# ---[START]text before modifying:---
# RT @bugheadfilms: happy anniversary to jughead finally getting the girl🥺 #Riverdale  https://t.co/ZUZ1LLUTfo
# ---Emoji modified text---
# rt @bugheadfilms: happy anniversary to jughead finally getting the girl:pleading_face: #riverdale  https://t.co/zuz1llutfo
# ---Removed Unnecesary pieces---
# rt : happy anniversary to jughead finally getting the girl:pleading face: riverdale
# ---[END]---
# Text Split:
# ['rt', ':', 'happy', 'anniversary', 'to', 'jughead', 'finally', 'getting', 'the', 'girl:pleading', 'face:', 'riverdale']
# ---[START]text before modifying:---
# RT @reinhartbrina: it's been four years since we first saw betty and jughead's relationship blossom and turn into a beautiful bond that not…
# ---Emoji modified text---
# rt @reinhartbrina: it's been four years since we first saw betty and jughead's relationship blossom and turn into a beautiful bond that not…
# ---Removed Unnecesary pieces---
# rt : it's been four years since we first saw betty and jughead's relationship blossom and turn into a beautiful bond that not…
# ---[END]---
# Text Split:
# ['rt', ':', "it's", 'been', 'four', 'years', 'since', 'we', 'first', 'saw', 'betty', 'and', "jughead's", 'relationship', 'blossom', 'and', 'turn', 'into', 'a', 'beautiful', 'bond', 'that', 'not…']
# ---[START]text before modifying:---
# RT @ForsythesCooper: Also...
# What?   *chuckles*   What? https://t.co/nVfQYR8QhQ
# ---Emoji modified text---
# rt @forsythescooper: also...
# what?   *chuckles*   what? https://t.co/nvfqyr8qhq
# ---Removed Unnecesary pieces---
# rt : also...
# what?   *chuckles*   what?
# ---[END]---
# Text Split:
# ['rt', ':', 'also...', 'what?', '*chuckles*', 'what?']
# ---[START]text before modifying:---
# RT @fcrsythe: four years ago today, bughead had their first kiss... and the rest is history ❤️ https://t.co/Pkl4ennLe8
# ---Emoji modified text---
# rt @fcrsythe: four years ago today, bughead had their first kiss... and the rest is history :red_heart: https://t.co/pkl4ennle8
# ---Removed Unnecesary pieces---
# rt : four years ago today, bughead had their first kiss... and the rest is history :red heart:
# ---[END]---
# Text Split:
# ['rt', ':', 'four', 'years', 'ago', 'today,', 'bughead', 'had', 'their', 'first', 'kiss...', 'and', 'the', 'rest', 'is', 'history', ':red', 'heart:']
# ---[START]text before modifying:---
# RT @bugheadIines: hey. we’re all crazy. we’re not our parents, betty. we’re not our families. also-
# #riverdale https://t.co/fb11udntwc
# ---Emoji modified text---
# rt @bugheadiines: hey. we’re all crazy. we’re not our parents, betty. we’re not our families. also-
# #riverdale https://t.co/fb11udntwc
# ---Removed Unnecesary pieces---
# rt : hey. we’re all crazy. we’re not our parents, betty. we’re not our families. also-
# riverdale
# ---[END]---
# Text Split:
# ['rt', ':', 'hey.', 'we’re', 'all', 'crazy.', 'we’re', 'not', 'our', 'parents,', 'betty.', 'we’re', 'not', 'our', 'families.', 'also-', 'riverdale']
# ---[START]text before modifying:---
# RT @lovesicksprouse: if we get little jughead secretly crushing on betty, i'll collapse /pos https://t.co/KtjABHu68v
# ---Emoji modified text---
# rt @lovesicksprouse: if we get little jughead secretly crushing on betty, i'll collapse /pos https://t.co/ktjabhu68v
# ---Removed Unnecesary pieces---
# rt : if we get little jughead secretly crushing on betty, i'll collapse /pos
# ---[END]---
# Text Split:
# ['rt', ':', 'if', 'we', 'get', 'little', 'jughead', 'secretly', 'crushing', 'on', 'betty,', "i'll", 'collapse', '/pos']
# ---[START]text before modifying:---
# RT @wildestlili: when the writers made them endgame before we even saw them get together on screen❤️ #bughead https://t.co/aGEhqjHF6Z
# ---Emoji modified text---
# rt @wildestlili: when the writers made them endgame before we even saw them get together on screen:red_heart: #bughead https://t.co/agehqjhf6z
# ---Removed Unnecesary pieces---
# rt : when the writers made them endgame before we even saw them get together on screen:red heart: bughead
# ---[END]---
# Text Split:
# ['rt', ':', 'when', 'the', 'writers', 'made', 'them', 'endgame', 'before', 'we', 'even', 'saw', 'them', 'get', 'together', 'on', 'screen:red', 'heart:', 'bughead']
# ---[START]text before modifying:---
# RT @lilisjacey: it’s been four years since bughead’s first kiss and four seasons later jughead wrote a novel about his story with betty 🥺 h…
# ---Emoji modified text---
# rt @lilisjacey: it’s been four years since bughead’s first kiss and four seasons later jughead wrote a novel about his story with betty :pleading_face: h…
# ---Removed Unnecesary pieces---
# rt : it’s been four years since bughead’s first kiss and four seasons later jughead wrote a novel about his story with betty :pleading face: h…
# ---[END]---
# Text Split:
# ['rt', ':', 'it’s', 'been', 'four', 'years', 'since', 'bughead’s', 'first', 'kiss', 'and', 'four', 'seasons', 'later', 'jughead', 'wrote', 'a', 'novel', 'about', 'his', 'story', 'with', 'betty', ':pleading', 'face:', 'h…']
# ---[START]text before modifying:---
# RT @juqheadjonez: he was so nervous to kiss her https://t.co/eT3C9KbKhG
# ---Emoji modified text---
# rt @juqheadjonez: he was so nervous to kiss her https://t.co/et3c9kbkhg
# ---Removed Unnecesary pieces---
# rt : he was so nervous to kiss her
# ---[END]---
# Text Split:
# ['rt', ':', 'he', 'was', 'so', 'nervous', 'to', 'kiss', 'her']
# ---[START]text before modifying:---
# RT @itsreinhartt: this parallel https://t.co/ym6RAZXU6E
# ---Emoji modified text---
# rt @itsreinhartt: this parallel https://t.co/ym6razxu6e
# ---Removed Unnecesary pieces---
# rt : this parallel
# ---[END]---
# Text Split:
# ['rt', ':', 'this', 'parallel']
# ---[START]text before modifying:---
# RT @buvghead: he’s sick😭 https://t.co/Xmgz60VUF2
# ---Emoji modified text---
# rt @buvghead: he’s sick:loudly_crying_face: https://t.co/xmgz60vuf2
# ---Removed Unnecesary pieces---
# rt : he’s sick:loudly crying face:
# ---[END]---
# Text Split:
# ['rt', ':', 'he’s', 'sick:loudly', 'crying', 'face:']
# ---[START]text before modifying:---
# @drea_crea It didn’t exist as 99% of the arguments that fandom uses to say Bughead is endgame
# ---Emoji modified text---
# @drea_crea it didn’t exist as 99% of the arguments that fandom uses to say bughead is endgame
# ---Removed Unnecesary pieces---
#  crea it didn’t exist as 99% of the arguments that fandom uses to say bughead is endgame
# ---[END]---
# Text Split:
# ['crea', 'it', 'didn’t', 'exist', 'as', '99%', 'of', 'the', 'arguments', 'that', 'fandom', 'uses', 'to', 'say', 'bughead', 'is', 'endgame']
# ---[START]text before modifying:---
# RT @jenniesivy: they're so pretty to me https://t.co/NMJiUJfqq3
# ---Emoji modified text---
# rt @jenniesivy: they're so pretty to me https://t.co/nmjiujfqq3
# ---Removed Unnecesary pieces---
# rt : they're so pretty to me
# ---[END]---
# Text Split:
# ['rt', ':', "they're", 'so', 'pretty', 'to', 'me']
# ---[START]text before modifying:---
# RT @reinhartbrina: can we talk about how happy they both were in their first kiss 🥺 https://t.co/Nn5pnMJG7h
# ---Emoji modified text---
# rt @reinhartbrina: can we talk about how happy they both were in their first kiss :pleading_face: https://t.co/nn5pnmjg7h
# ---Removed Unnecesary pieces---
# rt : can we talk about how happy they both were in their first kiss :pleading face:
# ---[END]---
# Text Split:
# ['rt', ':', 'can', 'we', 'talk', 'about', 'how', 'happy', 'they', 'both', 'were', 'in', 'their', 'first', 'kiss', ':pleading', 'face:']
# ---[START]text before modifying:---
# RT @bugheadfilms: HE IS INSANE ? https://t.co/lQ9bO3LXGk
# ---Emoji modified text---
# rt @bugheadfilms: he is insane ? https://t.co/lq9bo3lxgk
# ---Removed Unnecesary pieces---
# rt : he is insane ?
# ---[END]---
# Text Split:
# ['rt', ':', 'he', 'is', 'insane', '?']
# ---[START]text before modifying:---
# RT @ForsythesCooper: Weirdly being in the woods with you investigating something crazy is the least stressful most normal thing i can think…
# ---Emoji modified text---
# rt @forsythescooper: weirdly being in the woods with you investigating something crazy is the least stressful most normal thing i can think…
# ---Removed Unnecesary pieces---
# rt : weirdly being in the woods with you investigating something crazy is the least stressful most normal thing i can think…
# ---[END]---
# Text Split:
# ['rt', ':', 'weirdly', 'being', 'in', 'the', 'woods', 'with', 'you', 'investigating', 'something', 'crazy', 'is', 'the', 'least', 'stressful', 'most', 'normal', 'thing', 'i', 'can', 'think…']
# ---[START]text before modifying:---
# RT @bugheadconfess_: It will always be them https://t.co/mnTjcKdOo1
# ---Emoji modified text---
# rt @bugheadconfess_: it will always be them https://t.co/mntjckdoo1
# ---Removed Unnecesary pieces---
# rt  : it will always be them
# ---[END]---
# Text Split:
# ['rt', ':', 'it', 'will', 'always', 'be', 'them']
# ---[START]text before modifying:---
# RT @jenniesivy: their blue and gold aesthetic is so pretty https://t.co/dgeFkEja2K
# ---Emoji modified text---
# rt @jenniesivy: their blue and gold aesthetic is so pretty https://t.co/dgefkeja2k
# ---Removed Unnecesary pieces---
# rt : their blue and gold aesthetic is so pretty
# ---[END]---
# Text Split:
# ['rt', ':', 'their', 'blue', 'and', 'gold', 'aesthetic', 'is', 'so', 'pretty']
# ---[START]text before modifying:---
# RT @uncoIesprouse: Cole Sprouse is beautiful
# ---Emoji modified text---
# rt @uncoiesprouse: cole sprouse is beautiful
# ---Removed Unnecesary pieces---
# rt : cole sprouse is beautiful
# ---[END]---
# Text Split:
# ['rt', ':', 'cole', 'sprouse', 'is', 'beautiful']
# ---[START]text before modifying:---
# RT @juqheadjonez: jughead came out of his comfort zone and took one step in overcoming his fear of rejection by kissing betty, and thats sa…
# ---Emoji modified text---
# rt @juqheadjonez: jughead came out of his comfort zone and took one step in overcoming his fear of rejection by kissing betty, and thats sa…
# ---Removed Unnecesary pieces---
# rt : jughead came out of his comfort zone and took one step in overcoming his fear of rejection by kissing betty, and thats sa…
# ---[END]---
# Text Split:
# ['rt', ':', 'jughead', 'came', 'out', 'of', 'his', 'comfort', 'zone', 'and', 'took', 'one', 'step', 'in', 'overcoming', 'his', 'fear', 'of', 'rejection', 'by', 'kissing', 'betty,', 'and', 'thats', 'sa…']
# ---[START]text before modifying:---
# RT @fcrsythe: jughead pushed aside his fear of being hurt and rejected because his feelings for betty were way to strong to ignore. let tha…
# ---Emoji modified text---
# rt @fcrsythe: jughead pushed aside his fear of being hurt and rejected because his feelings for betty were way to strong to ignore. let tha…
# ---Removed Unnecesary pieces---
# rt : jughead pushed aside his fear of being hurt and rejected because his feelings for betty were way to strong to ignore. let tha…
# ---[END]---
# Text Split:
# ['rt', ':', 'jughead', 'pushed', 'aside', 'his', 'fear', 'of', 'being', 'hurt', 'and', 'rejected', 'because', 'his', 'feelings', 'for', 'betty', 'were', 'way', 'to', 'strong', 'to', 'ignore.', 'let', 'tha…']
# ---[START]text before modifying:---
# RT @jcghaed: Cole sprouse could be straight up making out with someone and y'all will still do
# "they could be just friends"
# ---Emoji modified text---
# rt @jcghaed: cole sprouse could be straight up making out with someone and y'all will still do
# "they could be just friends"
# ---Removed Unnecesary pieces---
# ...
# ---[START]text before modifying:---
# @hicbiseybuya bughead degil benim fav ciftim varchie
# ---Emoji modified text---
# @hicbiseybuya bughead degil benim fav ciftim varchie
# ---Removed Unnecesary pieces---
#  bughead degil benim fav ciftim varchie
# ---[END]---
# Text Split:
# ['bughead', 'degil', 'benim', 'fav', 'ciftim', 'varchie']
# ---[START]text before modifying:---
# @archswonderwall And again cinematic excellence. This had a long time coming, but here it finally was and from this point I knew there was no going back. Nothing could be the same with Bughead and Varchie after this episode. https://t.co/lsAg9oVAYI
# ---Emoji modified text---
# @archswonderwall and again cinematic excellence. this had a long time coming, but here it finally was and from this point i knew there was no going back. nothing could be the same with bughead and varchie after this episode. https://t.co/lsag9ovayi
# ---Removed Unnecesary pieces---
#  and again cinematic excellence. this had a long time coming, but here it finally was and from this point i knew there was no going back. nothing could be the same with bughead and varchie after this episode.
# ---[END]---
# Text Split:
# ['and', 'again', 'cinematic', 'excellence.', 'this', 'had', 'a', 'long', 'time', 'coming,', 'but', 'here', 'it', 'finally', 'was', 'and', 'from', 'this', 'point', 'i', 'knew', 'there', 'was', 'no', 'going', 'back.', 'nothing', 'could', 'be', 'the', 'same', 'with', 'bughead', 'and', 'varchie', 'after', 'this', 'episode.']
# ---[START]text before modifying:---
# GIVE ME BACK MY BUGHEAD PLEASE🥺 https://t.co/GoTRkgzSn5
# ---Emoji modified text---
# give me back my bughead please:pleading_face: https://t.co/gotrkgzsn5
# ---Removed Unnecesary pieces---
# give me back my bughead please:pleading face:
# ---[END]---
# Text Split:
# ['give', 'me', 'back', 'my', 'bughead', 'please:pleading', 'face:']
# ---[START]text before modifying:---
# RT @robynchoni: i want varchie to be endgame but not bughead because ew. https://t.co/Dmb0wPhhzu
# ---Emoji modified text---
# rt @robynchoni: i want varchie to be endgame but not bughead because ew. https://t.co/dmb0wphhzu
# ---Removed Unnecesary pieces---
# rt : i want varchie to be endgame but not bughead because ew.
# ---[END]---
# Text Split:
# ['rt', ':', 'i', 'want', 'varchie', 'to', 'be', 'endgame', 'but', 'not', 'bughead', 'because', 'ew.']
# ---[START]text before modifying:---
# RT @bugheadbebs: PLEASE TALK MORE ABOUT CHERYL'S AESTHETIC IN S5, IM OBSESSED DOSJHSJSJ
# ---Emoji modified text---
# rt @bugheadbebs: please talk more about cheryl's aesthetic in s5, im obsessed dosjhsjsj
# ---Removed Unnecesary pieces---
# rt : please talk more about cheryl's aesthetic in s5, im obsessed dosjhsjsj
# ---[END]---
# Text Split:
# ['rt', ':', 'please', 'talk', 'more', 'about', "cheryl's", 'aesthetic', 'in', 's5,', 'im', 'obsessed', 'dosjhsjsj']
# ---[START]text before modifying:---
# I just want to said that Riverdale was too easily when they could goin to the Pop's in the finale chapter, but I hope they'll be happy (principally bughead haha)
# ---Emoji modified text---
# i just want to said that riverdale was too easily when they could goin to the pop's in the finale chapter, but i hope they'll be happy (principally bughead haha)
# ---Removed Unnecesary pieces---
# i just want to said that riverdale was too easily when they could goin to the pop's in the finale chapter, but i hope they'll be happy (principally bughead haha)
# ---[END]---
# Text Split:
# ['i', 'just', 'want', 'to', 'said', 'that', 'riverdale', 'was', 'too', 'easily', 'when', 'they', 'could', 'goin', 'to', 'the', "pop's", 'in', 'the', 'finale', 'chapter,', 'but', 'i', 'hope', "they'll", 'be', 'happy', '(principally', 'bughead', 'haha)']
# ---[START]text before modifying:---
# @Deckerstar_6666 Bughead used to win these polls by over 70% when I was still a hardcore riverdale fan. I wonder what happened 🤣🤣
# ---Emoji modified text---
# @deckerstar_6666 bughead used to win these polls by over 70% when i was still a hardcore riverdale fan. i wonder what happened :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:
# ---Removed Unnecesary pieces---
#  6666 bughead used to win these polls by over 70% when i was still a hardcore riverdale fan. i wonder what happened :rolling on the floor laughing::rolling on the floor laughing:
# ---[END]---
# Text Split:
# ['6666', 'bughead', 'used', 'to', 'win', 'these', 'polls', 'by', 'over', '70%', 'when', 'i', 'was', 'still', 'a', 'hardcore', 'riverdale', 'fan.', 'i', 'wonder', 'what', 'happened', ':rolling', 'on', 'the', 'floor', 'laughing::rolling', 'on', 'the', 'floor', 'laughing:']
# ---[START]text before modifying:---
# @dear_patience_1 Bughead
# ---Emoji modified text---
# @dear_patience_1 bughead
# ---Removed Unnecesary pieces---
#  patience 1 bughead
# ---[END]---
# Text Split:
# ['patience', '1', 'bughead']
# ---[START]text before modifying:---
# i want varchie to be endgame but not bughead because ew. https://t.co/Dmb0wPhhzu
# ---Emoji modified text---
# i want varchie to be endgame but not bughead because ew. https://t.co/dmb0wphhzu
# ---Removed Unnecesary pieces---
# i want varchie to be endgame but not bughead because ew.
# ---[END]---
# Text Split:
# ['i', 'want', 'varchie', 'to', 'be', 'endgame', 'but', 'not', 'bughead', 'because', 'ew.']
# ---[START]text before modifying:---
# RT @FainChloe: I love Jughead with my whole heart that’s all I had to say https://t.co/ukS1l3BRGs
# ---Emoji modified text---
# rt @fainchloe: i love jughead with my whole heart that’s all i had to say https://t.co/uks1l3brgs
# ---Removed Unnecesary pieces---
# rt : i love jughead with my whole heart that’s all i had to say
# ---[END]---
# Text Split:
# ['rt', ':', 'i', 'love', 'jughead', 'with', 'my', 'whole', 'heart', 'that’s', 'all', 'i', 'had', 'to', 'say']
# ---[START]text before modifying:---
# RT @Aestheticlils: Again, they’re gonna be such a gorgeous couple.
#
# #bughead #riverdale https://t.co/6gIwu0ZVyL
# ---Emoji modified text---
# rt @aestheticlils: again, they’re gonna be such a gorgeous couple.
#
# #bughead #riverdale https://t.co/6giwu0zvyl
# ---Removed Unnecesary pieces---
# rt : again, they’re gonna be such a gorgeous couple.
#
# bughead riverdale
# ---[END]---
# Text Split:
# ['rt', ':', 'again,', 'they’re', 'gonna', 'be', 'such', 'a', 'gorgeous', 'couple.', 'bughead', 'riverdale']
# ---[START]text before modifying:---
# Normalize blaming everything on Bughead and it's shippers. I'll start.
# I can't get in on Identity V since Chinese New Year cuz of Bughead shippers
# ---Emoji modified text---
# normalize blaming everything on bughead and it's shippers. i'll start.
# i can't get in on identity v since chinese new year cuz of bughead shippers
# ---Removed Unnecesary pieces---
# normalize blaming everything on bughead and it's shippers. i'll start.
# i can't get in on identity v since chinese new year cuz of bughead shippers
# ---[END]---
# Text Split:
# ['normalize', 'blaming', 'everything', 'on', 'bughead', 'and', "it's", 'shippers.', "i'll", 'start.', 'i', "can't", 'get', 'in', 'on', 'identity', 'v', 'since', 'chinese', 'new', 'year', 'cuz', 'of', 'bughead', 'shippers']
# ---[START]text before modifying:---
# Team Varchie! #Riverdale
# ---Emoji modified text---
# team varchie! #riverdale
# ---Removed Unnecesary pieces---
# team varchie! riverdale
# ---[END]---
# Text Split:
# ['team', 'varchie!', 'riverdale']
# ---[START]text before modifying:---
# RT @jugschandler: do this i’m bored https://t.co/PdZEDwOiy9
# ---Emoji modified text---
# rt @jugschandler: do this i’m bored https://t.co/pdzedwoiy9
# ---Removed Unnecesary pieces---
# rt : do this i’m bored
# ---[END]---
# Text Split:
# ['rt', ':', 'do', 'this', 'i’m', 'bored']
# ---[START]text before modifying:---
# The way he looks at her is just- *crying*🥺#Jughead #jughead #bughead #betty https://t.co/Dv3JVdiy6V
# ---Emoji modified text---
# the way he looks at her is just- *crying*:pleading_face:#jughead #jughead #bughead #betty https://t.co/dv3jvdiy6v
# ---Removed Unnecesary pieces---
# the way he looks at her is just- *crying*:pleading face:jughead jughead bughead betty
# ---[END]---
# Text Split:
# ['the', 'way', 'he', 'looks', 'at', 'her', 'is', 'just-', '*crying*:pleading', 'face:jughead', 'jughead', 'bughead', 'betty']
# ---[START]text before modifying:---
# going to school later losers
# ---Emoji modified text---
# going to school later losers
# ---Removed Unnecesary pieces---
# going to school later losers
# ---[END]---
# Text Split:
# ['going', 'to', 'school', 'later', 'losers']
# ---[START]text before modifying:---
# @greenjeaans That is exactly my point...but I've love Bughead also......
# Peace🥀✌
# ---Emoji modified text---
# @greenjeaans that is exactly my point...but i've love bughead also......
# peace:wilted_flower::victory_hand:
# ---Removed Unnecesary pieces---
#  that is exactly my point...but i've love bughead also......
# peace:wilted flower::victory hand:
# ---[END]---
# Text Split:
# ['that', 'is', 'exactly', 'my', 'point...but', "i've", 'love', 'bughead', 'also......', 'peace:wilted', 'flower::victory', 'hand:']
# ---[START]text before modifying:---
# what do you think of bughead ? — cute and excited where their story is going this season  https://t.co/axpkH19Nxc
# ---Emoji modified text---
# what do you think of bughead ? — cute and excited where their story is going this season  https://t.co/axpkh19nxc
# ---Removed Unnecesary pieces---
# what do you think of bughead ? — cute and excited where their story is going this season
# ---[END]---
# Text Split:
# ['what', 'do', 'you', 'think', 'of', 'bughead', '?', '—', 'cute', 'and', 'excited', 'where', 'their', 'story', 'is', 'going', 'this', 'season']
# ---[START]text before modifying:---
# @yasminfandoms Season 5 is a lot like the time jump of PLL and the OG ships all got back together there. I’m enjoying Barchie sex but bughead is likely going to be together pretty soon. Especially if Polly is the one who died.
# ---Emoji modified text---
# @yasminfandoms season 5 is a lot like the time jump of pll and the og ships all got back together there. i’m enjoying barchie sex but bughead is likely going to be together pretty soon. especially if polly is the one who died.
# ---Removed Unnecesary pieces---
#  season 5 is a lot like the time jump of pll and the og ships all got back together there. i’m enjoying barchie sex but bughead is likely going to be together pretty soon. especially if polly is the one who died.
# ---[END]---
# Text Split:
# ['season', '5', 'is', 'a', 'lot', 'like', 'the', 'time', 'jump', 'of', 'pll', 'and', 'the', 'og', 'ships', 'all', 'got', 'back', 'together', 'there.', 'i’m', 'enjoying', 'barchie', 'sex', 'but', 'bughead', 'is', 'likely', 'going', 'to', 'be', 'together', 'pretty', 'soon.', 'especially', 'if', 'polly', 'is', 'the', 'one', 'who', 'died.']
# ---[START]text before modifying:---
# @CW_Riverdale Please bring back bughead
# ---Emoji modified text---
# @cw_riverdale please bring back bughead
# ---Removed Unnecesary pieces---
#  riverdale please bring back bughead
# ---[END]---
# Text Split:
# ['riverdale', 'please', 'bring', 'back', 'bughead']
# ---[START]text before modifying:---
# @yasminfandoms Barchie definitely isn’t endgame. They are just f buddies. This is a teen drama. Bughead and Varchie are the relationships that have always been there as endgame and Choni. You don’t have to agree but it’s how these shows work.
# ---Emoji modified text---
# @yasminfandoms barchie definitely isn’t endgame. they are just f buddies. this is a teen drama. bughead and varchie are the relationships that have always been there as endgame and choni. you don’t have to agree but it’s how these shows work.
# ---Removed Unnecesary pieces---
#  barchie definitely isn’t endgame. they are just f buddies. this is a teen drama. bughead and varchie are the relationships that have always been there as endgame and choni. you don’t have to agree but it’s how these shows work.
# ---[END]---
# Text Split:
# ['barchie', 'definitely', 'isn’t', 'endgame.', 'they', 'are', 'just', 'f', 'buddies.', 'this', 'is', 'a', 'teen', 'drama.', 'bughead', 'and', 'varchie', 'are', 'the', 'relationships', 'that', 'have', 'always', 'been', 'there', 'as', 'endgame', 'and', 'choni.', 'you', 'don’t', 'have', 'to', 'agree', 'but', 'it’s', 'how', 'these', 'shows', 'work.']
# ---[START]text before modifying:---
# @BarchieUpdates Noo, bughead #4ever
# ---Emoji modified text---
# @barchieupdates noo, bughead #4ever
# ---Removed Unnecesary pieces---
#  noo, bughead 4ever
# ---[END]---
# Text Split:
# ['noo,', 'bughead', '4ever']
# ---[START]text before modifying:---
# meu pai me mandando gif de bughead KKKKKKKKVOU ME M-
# ---Emoji modified text---
# meu pai me mandando gif de bughead kkkkkkkkvou me m-
# ---Removed Unnecesary pieces---
# meu pai me mandando gif de bughead kkkkkkkkvou me m-
# ---[END]---
# Text Split:
# ['meu', 'pai', 'me', 'mandando', 'gif', 'de', 'bughead', 'kkkkkkkkvou', 'me', 'm-']
# ---[START]text before modifying:---
# @barchiecanons5 @rytbone @Barchiedaily He may be saying he likes Bughead and Barchie. Or that's Betty and Glenn. Not sure.
# ---Emoji modified text---
# @barchiecanons5 @rytbone @barchiedaily he may be saying he likes bughead and barchie. or that's betty and glenn. not sure.
# ---Removed Unnecesary pieces---
#    he may be saying he likes bughead and barchie. or that's betty and glenn. not sure.
# ---[END]---
# Text Split:
# ['he', 'may', 'be', 'saying', 'he', 'likes', 'bughead', 'and', 'barchie.', 'or', "that's", 'betty', 'and', 'glenn.', 'not', 'sure.']
# ---[START]text before modifying:---
# @ChaosPper @NessaJ785 Yeah, IMO bughead is toxic af, as a 16 yo betty stripped in from of 40 yo's to be part of his world, that's so messed up,and when there is even a slight problem in their relationship she goes back to Archie,IMO that's something that wouldn't happen if she felt strong enough abt J
# ---Emoji modified text---
# @chaospper @nessaj785 yeah, imo bughead is toxic af, as a 16 yo betty stripped in from of 40 yo's to be part of his world, that's so messed up,and when there is even a slight problem in their relationship she goes back to archie,imo that's something that wouldn't happen if she felt strong enough abt j
# ---Removed Unnecesary pieces---
#   yeah, imo bughead is toxic af, as a 16 yo betty stripped in from of 40 yo's to be part of his world, that's so messed up,and when there is even a slight problem in their relationship she goes back to archie,imo that's something that wouldn't happen if she felt strong enough abt j
# ---[END]---
# Text Split:
# ['yeah,', 'imo', 'bughead', 'is', 'toxic', 'af,', 'as', 'a', '16', 'yo', 'betty', 'stripped', 'in', 'from', 'of', '40', "yo's", 'to', 'be', 'part', 'of', 'his', 'world,', "that's", 'so', 'messed', 'up,and', 'when', 'there', 'is', 'even', 'a', 'slight', 'problem', 'in', 'their', 'relationship', 'she', 'goes', 'back', 'to', 'archie,imo', "that's", 'something', 'that', "wouldn't", 'happen', 'if', 'she', 'felt', 'strong', 'enough', 'abt', 'j']
# ---[START]text before modifying:---
# @Lauraisback25 I don't think they will, and honestly after what is happening with Barchie, I don't really think they will get back together. If Barchie isn't endgame I don't think Bughead or Varchie will be either. But let us watch and see, no reason to argue about it
# ---Emoji modified text---
# @lauraisback25 i don't think they will, and honestly after what is happening with barchie, i don't really think they will get back together. if barchie isn't endgame i don't think bughead or varchie will be either. but let us watch and see, no reason to argue about it
# ---Removed Unnecesary pieces---
#  i don't think they will, and honestly after what is happening with barchie, i don't really think they will get back together. if barchie isn't endgame i don't think bughead or varchie will be either. but let us watch and see, no reason to argue about it
# ---[END]---
# Text Split:
# ['i', "don't", 'think', 'they', 'will,', 'and', 'honestly', 'after', 'what', 'is', 'happening', 'with', 'barchie,', 'i', "don't", 'really', 'think', 'they', 'will', 'get', 'back', 'together.', 'if', 'barchie', "isn't", 'endgame', 'i', "don't", 'think', 'bughead', 'or', 'varchie', 'will', 'be', 'either.', 'but', 'let', 'us', 'watch', 'and', 'see,', 'no', 'reason', 'to', 'argue', 'about', 'it']

# %%
choni_csv["cleaned_tweets"] = cleanedTweets
choni_csv["neg"] = sentimentPos
choni_csv["neu"] = sentimentNeg
choni_csv["pos"] = sentimentNeu
choni_csv["neg"] = choni_csv["neg"].astype(float)
choni_csv["neu"] = choni_csv["neu"].astype(float)
choni_csv["pos"] = choni_csv["pos"].astype(float)
choni_csv["neg"] = choni_csv["neg"].map('{:,.2f}'.format)
choni_csv["neu"] = choni_csv["neu"].map('{:,.2f}'.format)
choni_csv["pos"] = choni_csv["pos"].map('{:,.2f}'.format)
choni_csv.head(10)
# Out:
#                                               tweets  quote_status language  \
# 0  Bughead was never meant to be a main couple on...         False       en
# 1                   (especially on bughead day) HELP         False       en
# 2  her little smile after it END OF DISCUSSION BU...         False       en
# 3  RT @lovemesometopaz: if you still think bughea...         False       en
# 4  RT @BugheadGif: four years ago today, jughead ...         False       en
# 5  RT @mitchelsdemhawk: hating on bughead and var...         False       en
# 6  RT @bugheadaIe: saying bughead was never suppo...         False       en
# 7               RAS is a huge Bughead, he has taste.         False       en
# 8  RT @BugheadUpdates: 4 years ago today, Jughead...         False       en
# 9  RT @BamSmackPow: On this day we celebrate one ...         False       en
#
#    favorite_count  retweet_count                 time                   id  \
# 0               0              0  2021-03-03 00:56:53  1366915446918828033
# 1               0              0  2021-03-03 00:56:50  1366915433287217152
# 2               3              0  2021-03-03 00:54:58  1366914965056192515
# 3               0             97  2021-03-03 00:54:34  1366914865089101832
# 4               0             74  2021-03-03 00:54:13  1366914777289744384
# 5               0              2  2021-03-03 00:45:22  1366912550407983112
# 6               0             31  2021-03-03 00:43:18  1366912029840318466
# 7               1              0  2021-03-03 00:42:19  1366911780702875651
# 8               0            153  2021-03-03 00:41:24  1366911550875926531
# 9               0             14  2021-03-03 00:38:30  1366910822807658496
#
#                                               rating  \
# 0  {'neg': 0.126, 'neu': 0.834, 'pos': 0.04, 'com...
# 1  {'neg': 0.0, 'neu': 0.538, 'pos': 0.462, 'comp...
# 2  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 0.76, 'pos': 0.24, 'compou...
# 5  {'neg': 0.191, 'neu': 0.809, 'pos': 0.0, 'comp...
# 6  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7  {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'comp...
# 8  {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'comp...
# 9  {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'comp...
#
#                                       processed_text  \
# 0  ['bughead', 'never', 'meant', 'main', 'couple'...
# 1           ['especially', 'bughead', 'day', 'help']
# 2  ['little', 'smile', 'end', 'discussion', 'bugh...
# 3  ['still', 'think', 'bughead', 'always', 'suppo...
# 4  ['four', 'years', 'ago', 'today', 'jughead', '...
# 5  ['hating', 'bughead', 'varchie', 'serve', 'yal...
# 6  ['saying', 'bughead', 'never', 'supposed', 'ma...
# 7                ['ras', 'huge', 'bughead', 'taste']
# 8  ['4', 'years', 'ago', 'today', 'jughead', 'cli...
# 9  ['day', 'celebrate', 'one', 'riverdale', 'endg...
#
#                                       cleaned_tweets   neg   neu   pos
# 0  bughead was never meant to be a main couple on...  0.00  0.00  1.00
# 1                   (especially on bughead day) help  0.00  0.00  1.00
# 2  her little smile after it end of discussion bu...  0.10  0.00  0.90
# 3  rt : if you still think bughead was always sup...  0.00  0.00  1.00
# 4  rt : four years ago today, jughead jones climb...  0.05  0.00  0.95
# 5  rt : hating on bughead and varchie is not the ...  0.00  0.00  1.00
# 6  rt : saying bughead was never supposed to be a...  0.00  0.00  1.00
# 7               ras is a huge bughead, he has taste.  0.00  0.00  1.00
# 8  rt : 4 years ago today, jughead climbed up to ...  0.05  0.00  0.95
# 9  rt : on this day we celebrate one of riverdale...  0.11  0.00  0.89

# %%
# save in df
choni_csv.to_csv('bughead_new_rba.csv',index=False)
