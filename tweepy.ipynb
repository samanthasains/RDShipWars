# %%
import tweepy
import pandas as pd

# %%
# %run ./keys.ipynb

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
number_of_tweets = 15000
tweets = []
quote_status = []
lang = []
favorite_count = []
retweet_count = []
time = []
tweet_id = []

for i in tweepy.Cursor(api.search, q = "veggie", tweet_mode="extended", wait_on_rate_limit="True").items(number_of_tweets):
    tweets.append(i.full_text)
    quote_status.append(i.is_quote_status)
    lang.append(i.lang)
    favorite_count.append(i.favorite_count)
    retweet_count.append(i.retweet_count)
    time.append(i.created_at)
    tweet_id.append(i.id)

# %%
# full_text
# geo (??)
# is_quote_status
# lang
# favorite_count
# retweet (??)
# retweet_count

# %%
df = pd.DataFrame({'tweets': tweets, 'quote_status': quote_status, 'language': lang, 'favorite_count': favorite_count, 'retweet_count': retweet_count, 'time':time, "id":tweet_id})

# %%
df
# Out:
#                                                 tweets  quote_status language  \
# 0    RT @chqmbies: #riverdale : smells like bugvarc...         False       en
# 1    RT @chqmbies: #riverdale : smells like bugvarc...         False       en
# 2    RT @chqmbies: #riverdale : smells like bugvarc...         False       en
# 3    RT @jenniesivy: @CW_Riverdale bughead endgame ...         False       en
# 4       @CW_Riverdale bughead endgame. that’s the tea.         False       en
# ..                                                 ...           ...      ...
# 863  @WarnerChannelLA BARCHIE. THE SUPERIOR SHIP OF...         False       en
# 864  riverdale barchie bughead varchie choni endgam...         False       en
# 865  Damn i knew @lilireinhart &amp; #KJAPA chemist...         False       en
# 866  RT @BugheadUpdates: @CW_Riverdale bughead endg...         False       en
# 867  @Minaslimme TUA:Ben jest underrated\nRiverdale...         False       pl
#
#      favorite_count  retweet_count                time                   id
# 0                 0             65 2021-02-27 07:40:59  1365567592795168769
# 1                 0             65 2021-02-27 07:24:21  1365563406376435713
# 2                 0             65 2021-02-27 07:20:30  1365562438050066432
# 3                 0             17 2021-02-27 07:19:41  1365562233162375168
# 4                 0              0 2021-02-27 07:06:10  1365558828771680257
# ..              ...            ...                 ...                  ...
# 863               1              0 2021-02-19 16:53:31  1362807537377169409
# 864               0              0 2021-02-19 15:17:49  1362783453595361283
# 865              10              0 2021-02-19 14:02:02  1362764383022178306
# 866               0             11 2021-02-19 14:01:03  1362764133842714626
# 867              22              0 2021-02-19 13:59:22  1362763711333728260
#
# [868 rows x 7 columns]

# %%
df.drop_duplicates(subset='tweets', inplace=True)

# %%
df
# Out:
#                                                  tweets  quote_status  \
# 0     RT @liberianlois: DSW please mind ur business ...         False
# 1     no cause if choni &amp; kangs had a joint wedd...         False
# 2     RT @monky_p: เสียดายโปรเจกต์นี้และเสียดายวงพริ...         False
# 3     RT @feifeiliu77: มิวไม่รู้ศัพท์พวกนี้เลยคับ นึ...         False
# 4     RT @small_kebab: Jotaro, The God of War 🩸🗡\n\n...         False
# ...                                                 ...           ...
# 2283  @mylittlefaith do you still think it’s kangs b...         False
# 2284  @riverindale when the swangs/kangs love triang...         False
# 2285  Idgaf about any ship but kangs I love kangs fo...         False
# 2286  @chonismaid like at worst it’s just the baby d...         False
# 2287  RT @tcpazs: i still think the odds of toni bei...         False
#
#      language  favorite_count  retweet_count                time  \
# 0          en               0             45 2021-02-27 15:43:12
# 1          en               0              0 2021-02-27 15:29:35
# 2          th               0            563 2021-02-27 15:28:01
# 3          th               0          23221 2021-02-27 15:27:26
# 4          en               0             27 2021-02-27 15:23:05
# ...       ...             ...            ...                 ...
# 2283       en               0              0 2021-02-19 23:16:59
# 2284       en               4              0 2021-02-19 23:09:05
# 2285       en               1              0 2021-02-19 22:55:46
# 2286       en               1              0 2021-02-19 22:45:16
# 2287       en               0              2 2021-02-19 22:35:17
#
#                        id
# 0     1365688944189452291
# 1     1365685519162642434
# 2     1365685125921398795
# 3     1365684978684600321
# 4     1365683884487290882
# ...                   ...
# 2283  1362904041898921984
# 2284  1362902051555049477
# 2285  1362898700872396801
# 2286  1362896058032922624
# 2287  1362893547708575746
#
# [1956 rows x 7 columns]

# %%
df=df[df.language =="en"]

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                 tweets  quote_status language  \
# 0    RT @liberianlois: DSW please mind ur business ...         False       en
# 1    no cause if choni &amp; kangs had a joint wedd...         False       en
# 2    RT @small_kebab: Jotaro, The God of War 🩸🗡\n\n...         False       en
# 3           @RewindNV Fujin should have Liu Kangs spot         False       en
# 4                                                Umays         False       en
# ..                                                 ...           ...      ...
# 686  @mylittlefaith do you still think it’s kangs b...         False       en
# 687  @riverindale when the swangs/kangs love triang...         False       en
# 688  Idgaf about any ship but kangs I love kangs fo...         False       en
# 689  @chonismaid like at worst it’s just the baby d...         False       en
# 690  RT @tcpazs: i still think the odds of toni bei...         False       en
#
#      favorite_count  retweet_count                time                   id
# 0                 0             45 2021-02-27 15:43:12  1365688944189452291
# 1                 0              0 2021-02-27 15:29:35  1365685519162642434
# 2                 0             27 2021-02-27 15:23:05  1365683884487290882
# 3                 2              0 2021-02-27 15:06:35  1365679730037579777
# 4                 0              0 2021-02-27 15:01:04  1365678341060063233
# ..              ...            ...                 ...                  ...
# 686               0              0 2021-02-19 23:16:59  1362904041898921984
# 687               4              0 2021-02-19 23:09:05  1362902051555049477
# 688               1              0 2021-02-19 22:55:46  1362898700872396801
# 689               1              0 2021-02-19 22:45:16  1362896058032922624
# 690               0              2 2021-02-19 22:35:17  1362893547708575746
#
# [691 rows x 7 columns]

# %%
df.to_csv('kangs.csv', index=False)
