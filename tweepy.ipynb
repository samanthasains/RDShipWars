# %%
import tweepy
import pandas as pd

# %%
# %run ./keys.ipynb

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
number_of_tweets = 15000
tweets = []
quote_status = []
lang = []
favorite_count = []
retweet_count = []
time = []
tweet_id = []

for i in tweepy.Cursor(api.search, q = "barchie", tweet_mode="extended", wait_on_rate_limit="True").items(number_of_tweets):
    tweets.append(i.full_text)
    quote_status.append(i.is_quote_status)
    lang.append(i.lang)
    favorite_count.append(i.favorite_count)
    retweet_count.append(i.retweet_count)
    time.append(i.created_at)
    tweet_id.append(i.id)

# %%
# full_text
# geo (??)
# is_quote_status
# lang
# favorite_count
# retweet (??)
# retweet_count

# %%
df = pd.DataFrame({'tweets': tweets, 'quote_status': quote_status, 'language': lang, 'favorite_count': favorite_count, 'retweet_count': retweet_count, 'time':time, "id":tweet_id})

# %%
df
# Out:
#                                                   tweets  quote_status  \
# 0      RT @ThatsRiverdale: Best part abt fwb between ...         False
# 1      RT @barchiewalker: NO BUT HE IS LITERALLY SLID...         False
# 2      @hopextete @vibezreinhart kkkkk não tenho culp...         False
# 3      RT @archiebstty: riverdale promoting barchie o...         False
# 4      @barcheated @michonnesconnie barchie nace slow...         False
# ...                                                  ...           ...
# 14995  RT @barchiedestiny: Can we all agree that \n\n...         False
# 14996  Actually Im not Varchie or barchie team, Archi...         False
# 14997  @winlex yeh like im team barchie but im not ma...         False
# 14998  @normanivixen it is so funny 😭we all thought i...         False
# 14999  RT @dylsbrien: people are already comparing bu...         False
#
#       language  favorite_count  retweet_count                time  \
# 0           en               0              1 2021-03-03 01:11:39
# 1           en               0              1 2021-03-03 01:10:48
# 2           pt               0              0 2021-03-03 01:08:53
# 3           en               0             46 2021-03-03 01:08:38
# 4           en               2              0 2021-03-03 01:08:22
# ...        ...             ...            ...                 ...
# 14995       en               0             80 2021-02-25 12:00:11
# 14996       en               0              0 2021-02-25 12:00:08
# 14997       en               0              0 2021-02-25 11:59:59
# 14998       en               2              0 2021-02-25 11:59:33
# 14999       en               0              6 2021-02-25 11:59:19
#
#                         id
# 0      1366919164384800770
# 1      1366918949355606021
# 2      1366918468537303040
# 3      1366918403026542595
# 4      1366918338207711235
# ...                    ...
# 14995  1364908045592113156
# 14996  1364908033239900165
# 14997  1364907993880399873
# 14998  1364907887076769796
# 14999  1364907826712371203
#
# [15000 rows x 7 columns]

# %%
df.drop_duplicates(subset='tweets', inplace=True)

# %%
df
# Out:
#                                                   tweets  quote_status  \
# 0      RT @ThatsRiverdale: Best part abt fwb between ...         False
# 1      RT @barchiewalker: NO BUT HE IS LITERALLY SLID...         False
# 2      @hopextete @vibezreinhart kkkkk não tenho culp...         False
# 3      RT @archiebstty: riverdale promoting barchie o...         False
# 4      @barcheated @michonnesconnie barchie nace slow...         False
# ...                                                  ...           ...
# 14993  Seguo l'hashtag #TheOC su instagram e mi esce ...         False
# 14994  @thisislaenw_ @rewritethwstars ben diziyi sevi...         False
# 14996  Actually Im not Varchie or barchie team, Archi...         False
# 14997  @winlex yeh like im team barchie but im not ma...         False
# 14998  @normanivixen it is so funny 😭we all thought i...         False
#
#       language  favorite_count  retweet_count                time  \
# 0           en               0              1 2021-03-03 01:11:39
# 1           en               0              1 2021-03-03 01:10:48
# 2           pt               0              0 2021-03-03 01:08:53
# 3           en               0             46 2021-03-03 01:08:38
# 4           en               2              0 2021-03-03 01:08:22
# ...        ...             ...            ...                 ...
# 14993       it               0              0 2021-02-25 12:01:11
# 14994       tr               1              0 2021-02-25 12:00:31
# 14996       en               0              0 2021-02-25 12:00:08
# 14997       en               0              0 2021-02-25 11:59:59
# 14998       en               2              0 2021-02-25 11:59:33
#
#                         id
# 0      1366919164384800770
# 1      1366918949355606021
# 2      1366918468537303040
# 3      1366918403026542595
# 4      1366918338207711235
# ...                    ...
# 14993  1364908298999373825
# 14994  1364908129612423168
# 14996  1364908033239900165
# 14997  1364907993880399873
# 14998  1364907887076769796
#
# [8562 rows x 7 columns]

# %%
df=df[df.language =="en"]

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                  tweets  quote_status  \
# 0     RT @ThatsRiverdale: Best part abt fwb between ...         False
# 1     RT @barchiewalker: NO BUT HE IS LITERALLY SLID...         False
# 2     RT @archiebstty: riverdale promoting barchie o...         False
# 3     @barcheated @michonnesconnie barchie nace slow...         False
# 4     RT @barchie247: Imagine varchie kisses and Arc...         False
# ...                                                 ...           ...
# 6913                        barchie in a car #Riverdale         False
# 6914  there is gonna be so much barchie in this ep i...         False
# 6915  Actually Im not Varchie or barchie team, Archi...         False
# 6916  @winlex yeh like im team barchie but im not ma...         False
# 6917  @normanivixen it is so funny 😭we all thought i...         False
#
#      language  favorite_count  retweet_count                time  \
# 0          en               0              1 2021-03-03 01:11:39
# 1          en               0              1 2021-03-03 01:10:48
# 2          en               0             46 2021-03-03 01:08:38
# 3          en               2              0 2021-03-03 01:08:22
# 4          en               0              1 2021-03-03 01:08:17
# ...       ...             ...            ...                 ...
# 6913       en               0              0 2021-02-25 12:03:27
# 6914       en               0              0 2021-02-25 12:02:16
# 6915       en               0              0 2021-02-25 12:00:08
# 6916       en               0              0 2021-02-25 11:59:59
# 6917       en               2              0 2021-02-25 11:59:33
#
#                        id
# 0     1366919164384800770
# 1     1366918949355606021
# 2     1366918403026542595
# 3     1366918338207711235
# 4     1366918318834126848
# ...                   ...
# 6913  1364908866442571777
# 6914  1364908571377369090
# 6915  1364908033239900165
# 6916  1364907993880399873
# 6917  1364907887076769796
#
# [6918 rows x 7 columns]

# %%
df.to_csv('barchie2.csv', index=False)
