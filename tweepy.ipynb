# %%
import tweepy
import pandas as pd

# %%
# %run ./keys.ipynb

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
number_of_tweets = 15000
tweets = []
quote_status = []
lang = []
favorite_count = []
retweet_count = []
time = []
tweet_id = []

for i in tweepy.Cursor(api.search, q = "doritos riverdale", tweet_mode="extended", wait_on_rate_limit="True").items(number_of_tweets):
    tweets.append(i.full_text)
    quote_status.append(i.is_quote_status)
    lang.append(i.lang)
    favorite_count.append(i.favorite_count)
    retweet_count.append(i.retweet_count)
    time.append(i.created_at)
    tweet_id.append(i.id)

# %%
# full_text
# geo (??)
# is_quote_status
# lang
# favorite_count
# retweet (??)
# retweet_count

# %%
df = pd.DataFrame({'tweets': tweets, 'quote_status': quote_status, 'language': lang, 'favorite_count': favorite_count, 'retweet_count': retweet_count, 'time':time, "id":tweet_id})

# %%
df
# Out:
#                                                 tweets  quote_status language  \
# 0    Oh le placement de produit @Doritos sur le der...         False       fr
# 1    RT @TVLine: Was #Riverdale Snack Out of Charac...         False       en
# 2    RT @TVLine: Was #Riverdale Snack Out of Charac...         False       en
# 3    RT @nocontextrvd: Doritos sales after this 📈 #...          True       en
# 4    RT @Darkbettyco: Exijo a Hiram Lodge en los co...         False       es
# ..                                                 ...           ...      ...
# 303  RT @_ligiamiranda: Hiram e propaganda do Dorit...         False       pt
# 304  O HIRAM COMENDO DORITOS 🗣️🗣️🗣️🗣️ #Riverdale @W...         False       pt
# 305       a propaganda de Doritos #PopsTalk #Riverdale         False       pt
# 306                  doritos ad placement on riverdale         False       fr
# 307      Hiram e propaganda do Doritos kkkk #Riverdale         False       pt
#
#      favorite_count  retweet_count                time                   id
# 0                 0              0 2021-02-27 15:37:47  1365687583368429575
# 1                 0              9 2021-02-27 15:03:41  1365678999230382082
# 2                 0              9 2021-02-27 11:15:02  1365621457036865540
# 3                 0             18 2021-02-27 09:04:04  1365588501614493698
# 4                 0              4 2021-02-27 08:53:02  1365585724955914240
# ..              ...            ...                 ...                  ...
# 303               0              2 2021-02-25 00:44:45  1364738066011860997
# 304             143             13 2021-02-25 00:44:44  1364738061356122117
# 305               0              0 2021-02-25 00:44:39  1364738040120418309
# 306               0              0 2021-02-25 00:44:28  1364737995887247364
# 307               1              2 2021-02-25 00:44:24  1364737978363428864
#
# [308 rows x 7 columns]

# %%
df.drop_duplicates(subset='tweets', inplace=True)

# %%
df
# Out:
#                                                 tweets  quote_status language  \
# 0    Oh le placement de produit @Doritos sur le der...         False       fr
# 1    RT @TVLine: Was #Riverdale Snack Out of Charac...         False       en
# 3    RT @nocontextrvd: Doritos sales after this 📈 #...          True       en
# 4    RT @Darkbettyco: Exijo a Hiram Lodge en los co...         False       es
# 5    RT @GhostBoyXXX999: I can't believe this is Ca...         False       en
# ..                                                 ...           ...      ...
# 300  Ta sendo patrocinado pela Doritos e HIRAM seu ...         False       pt
# 304  O HIRAM COMENDO DORITOS 🗣️🗣️🗣️🗣️ #Riverdale @W...         False       pt
# 305       a propaganda de Doritos #PopsTalk #Riverdale         False       pt
# 306                  doritos ad placement on riverdale         False       fr
# 307      Hiram e propaganda do Doritos kkkk #Riverdale         False       pt
#
#      favorite_count  retweet_count                time                   id
# 0                 0              0 2021-02-27 15:37:47  1365687583368429575
# 1                 0              9 2021-02-27 15:03:41  1365678999230382082
# 3                 0             18 2021-02-27 09:04:04  1365588501614493698
# 4                 0              4 2021-02-27 08:53:02  1365585724955914240
# 5                 0              1 2021-02-27 03:29:53  1365504398940463114
# ..              ...            ...                 ...                  ...
# 300               1              0 2021-02-25 00:45:04  1364738147603644418
# 304             143             13 2021-02-25 00:44:44  1364738061356122117
# 305               0              0 2021-02-25 00:44:39  1364738040120418309
# 306               0              0 2021-02-25 00:44:28  1364737995887247364
# 307               1              2 2021-02-25 00:44:24  1364737978363428864
#
# [203 rows x 7 columns]

# %%
df=df[df.language =="en"]

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                 tweets  quote_status language  \
# 1    RT @TVLine: Was #Riverdale Snack Out of Charac...         False       en
# 3    RT @nocontextrvd: Doritos sales after this 📈 #...          True       en
# 5    RT @GhostBoyXXX999: I can't believe this is Ca...         False       en
# 6    Doritos CMO: Tweettok this, instafsce that, bu...         False       en
# 7    RT @ArchieComics: @TVObsesssed Hiram found out...         False       en
# ..                                                 ...           ...      ...
# 279    I hope Hiram chokes on those Doritos #Riverdale         False       en
# 280                        Not the Doritos  #Riverdale         False       en
# 281     CRYING AT THE DORITOS SPONSOR 😂😂😂😂😂 #Riverdale         False       en
# 282      This episode sponsored by Doritos. #Riverdale         False       en
# 283  Hiram and that sweet Doritos product placement...         False       en
#
#      favorite_count  retweet_count                time                   id
# 1                 0              9 2021-02-27 15:03:41  1365678999230382082
# 3                 0             18 2021-02-27 09:04:04  1365588501614493698
# 5                 0              1 2021-02-27 03:29:53  1365504398940463114
# 6                 1              0 2021-02-27 02:38:59  1365491591041986561
# 7                 0              3 2021-02-27 02:30:10  1365489371483430920
# ..              ...            ...                 ...                  ...
# 279               1              0 2021-02-25 01:03:55  1364742892548415488
# 280               3              0 2021-02-25 01:03:55  1364742891210440706
# 281               1              0 2021-02-25 01:03:52  1364742876744286209
# 282               0              0 2021-02-25 01:03:47  1364742855890259972
# 283               0              0 2021-02-25 01:03:46  1364742852685799426
#
# [135 rows x 7 columns]

# %%
df.to_csv('doritos.csv', index=False)
