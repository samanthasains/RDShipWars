# %%
import tweepy
import pandas as pd

# %%
# %run ./keys.ipynb

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
number_of_tweets = 15000
tweets = []
quote_status = []
lang = []
favorite_count = []
retweet_count = []
time = []
tweet_id = []

for i in tweepy.Cursor(api.search, q = "time jump Riverdale", tweet_mode="extended", wait_on_rate_limit="True").items(number_of_tweets):
    tweets.append(i.full_text)
    quote_status.append(i.is_quote_status)
    lang.append(i.lang)
    favorite_count.append(i.favorite_count)
    retweet_count.append(i.retweet_count)
    time.append(i.created_at)
    tweet_id.append(i.id)

# %%
# full_text
# geo (??)
# is_quote_status
# lang
# favorite_count
# retweet (??)
# retweet_count

# %%
df = pd.DataFrame({'tweets': tweets, 'quote_status': quote_status, 'language': lang, 'favorite_count': favorite_count, 'retweet_count': retweet_count, 'time':time, "id":tweet_id})

# %%
df
# Out:
#                                                  tweets  quote_status  \
# 0     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# 1     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# 2     RT @BusinessOfLodge: Veronica Lodge \n\nlitera...         False
# 3     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# 4     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# ...                                                 ...           ...
# 1048  RT @J14Magazine: Things in #Riverdale can chan...         False
# 1049                  @ATI_KNEE https://t.co/ogYYz12SkC         False
# 1050  #Riverdale got their timeline wrong. If there ...         False
# 1051  RT @invcstigator: ㅤ\n\n            𝐄𝐋𝐈𝐙𝐀𝐁𝐄𝐓𝐇 𝐂...         False
# 1052  RT @invcstigator: ㅤ\n\n            𝐄𝐋𝐈𝐙𝐀𝐁𝐄𝐓𝐇 𝐂...         False
#
#      language  favorite_count  retweet_count                time  \
# 0          en               0            517 2021-02-27 00:24:07
# 1          en               0            517 2021-02-27 00:14:45
# 2          en               0              6 2021-02-27 00:13:14
# 3          en               0            517 2021-02-27 00:08:24
# 4          en               0            517 2021-02-27 00:04:51
# ...       ...             ...            ...                 ...
# 1048       en               0              3 2021-02-19 05:57:46
# 1049      und               1              0 2021-02-19 05:47:36
# 1050       en               0              0 2021-02-19 05:42:52
# 1051       en               0             22 2021-02-19 05:34:41
# 1052       en               0             22 2021-02-19 04:20:17
#
#                        id
# 0     1365457649370816514
# 1     1365455295288287232
# 2     1365454911329218562
# 3     1365453696767787009
# 4     1365452800843513856
# ...                   ...
# 1048  1362642512893140993
# 1049  1362639953516232704
# 1050  1362638763059523584
# 1051  1362636702213312513
# 1052  1362617981260492804
#
# [1053 rows x 7 columns]

# %%
df.drop_duplicates(subset='tweets', inplace=True)

# %%
df
# Out:
#                                                  tweets  quote_status  \
# 0     RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False
# 2     RT @BusinessOfLodge: Veronica Lodge \n\nlitera...         False
# 10    RT @TheWyrmQueen: Toni Topaz \n\n-Riverdale rp...         False
# 11    RT @BugheadUpdates: Time jump Jughead 👀 #River...         False
# 36    Veronica Lodge \n\nliterate/descriptive. canon...         False
# ...                                                 ...           ...
# 1046  considering going back to riverdale now that t...         False
# 1047  I love that Toni got a bigger role in Riverdal...         False
# 1048  RT @J14Magazine: Things in #Riverdale can chan...         False
# 1049                  @ATI_KNEE https://t.co/ogYYz12SkC         False
# 1050  #Riverdale got their timeline wrong. If there ...         False
#
#      language  favorite_count  retweet_count                time  \
# 0          en               0            517 2021-02-27 00:24:07
# 2          en               0              6 2021-02-27 00:13:14
# 10         en               0             31 2021-02-26 23:56:59
# 11         en               0             33 2021-02-26 23:41:49
# 36         en               6              6 2021-02-26 22:13:36
# ...       ...             ...            ...                 ...
# 1046       en               0              0 2021-02-19 06:22:58
# 1047       en               0              0 2021-02-19 06:02:02
# 1048       en               0              3 2021-02-19 05:57:46
# 1049      und               1              0 2021-02-19 05:47:36
# 1050       en               0              0 2021-02-19 05:42:52
#
#                        id
# 0     1365457649370816514
# 2     1365454911329218562
# 10    1365450823015276544
# 11    1365447004848013316
# 36    1365424806573731840
# ...                   ...
# 1046  1362648852998750211
# 1047  1362643585313742849
# 1048  1362642512893140993
# 1049  1362639953516232704
# 1050  1362638763059523584
#
# [406 rows x 7 columns]

# %%
df=df[df.language =="en"]

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                 tweets  quote_status language  \
# 0    RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
# 1    RT @BusinessOfLodge: Veronica Lodge \n\nlitera...         False       en
# 2    RT @TheWyrmQueen: Toni Topaz \n\n-Riverdale rp...         False       en
# 3    RT @BugheadUpdates: Time jump Jughead 👀 #River...         False       en
# 4    Veronica Lodge \n\nliterate/descriptive. canon...         False       en
# ..                                                 ...           ...      ...
# 379  after the time jump I am all about #Barchie, a...         False       en
# 380  considering going back to riverdale now that t...         False       en
# 381  I love that Toni got a bigger role in Riverdal...         False       en
# 382  RT @J14Magazine: Things in #Riverdale can chan...         False       en
# 383  #Riverdale got their timeline wrong. If there ...         False       en
#
#      favorite_count  retweet_count                time                   id
# 0                 0            515 2021-02-27 00:08:16  1365453661921546240
# 1                 0              5 2021-02-27 00:02:02  1365452091162980352
# 2                 0             31 2021-02-26 23:56:59  1365450823015276544
# 3                 0             33 2021-02-26 23:41:49  1365447004848013316
# 4                 5              5 2021-02-26 22:13:36  1365424806573731840
# ..              ...            ...                 ...                  ...
# 379               8              0 2021-02-19 06:41:02  1362653402363273216
# 380               0              0 2021-02-19 06:22:58  1362648852998750211
# 381               0              0 2021-02-19 06:02:02  1362643585313742849
# 382               0              3 2021-02-19 05:57:46  1362642512893140993
# 383               0              0 2021-02-19 05:42:52  1362638763059523584
#
# [384 rows x 7 columns]

# %%
df.to_csv('time_jump.csv', index=False)
