# %%
import tweepy
import pandas as pd

# %%
# %run ./keys.ipynb

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
number_of_tweets = 100
tweets = []
quote_status = []
lang = []
favorite_count = []
retweet_count = []
time = []
tweet_id = []

for i in tweepy.Cursor(api.search, q = "time jump Riverdale", tweet_mode="extended", wait_on_rate_limit="True"). items(number_of_tweets):
    tweets.append(i.full_text)
    quote_status.append(i.is_quote_status)
    lang.append(i.lang)
    favorite_count.append(i.favorite_count)
    retweet_count.append(i.retweet_count)
    time.append(i.created_at)
    tweet_id.append(i.id)

# %%
# full_text
# geo (??)
# is_quote_status
# lang
# favorite_count
# retweet (??)
# retweet_count

# %%
df = pd.DataFrame({'tweets': tweets, 'quote_status': quote_status, 'language': lang, 'favorite_count': favorite_count, 'retweet_count': retweet_count, 'time':time, "id":tweet_id})

# %%
df
# Out:
#                                                tweets  quote_status language  \
# 0   RT @BugheadUpdates: Time jump Jughead 👀 #River...         False       en
# 1   RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
# 2   RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
# 3   RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
# 4   RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
# ..                                                ...           ...      ...
# 95  RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
# 96  RT @TheWyrmQueen: Toni Topaz \n\n-Riverdale rp...         False       en
# 97  RT @TheWyrmQueen: Toni Topaz \n\n-Riverdale rp...         False       en
# 98  RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
# 99  RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
#
#     favorite_count  retweet_count                time                   id
# 0                0             33 2021-02-26 23:41:49  1365447004848013316
# 1                0            509 2021-02-26 23:35:13  1365445344063029250
# 2                0            509 2021-02-26 23:32:56  1365444767857991681
# 3                0            509 2021-02-26 23:31:51  1365444495114989568
# 4                0            509 2021-02-26 23:27:16  1365443342247604224
# ..             ...            ...                 ...                  ...
# 95               0            509 2021-02-26 19:42:21  1365386740043767812
# 96               0             30 2021-02-26 19:41:57  1365386641490149377
# 97               0             30 2021-02-26 19:39:46  1365386093328297986
# 98               0            509 2021-02-26 19:39:19  1365385979381616654
# 99               0            509 2021-02-26 19:38:05  1365385667950178308
#
# [100 rows x 7 columns]

# %%
df.drop_duplicates(subset='tweets', inplace=True)

# %%
df
# Out:
#                                                tweets  quote_status language  \
# 0   RT @BugheadUpdates: Time jump Jughead 👀 #River...         False       en
# 1   RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
# 6   RT @TheWyrmQueen: Toni Topaz \n\n-Riverdale rp...         False       en
# 17  RT @BusinessOfLodge: Veronica Lodge \n\nlitera...         False       en
# 25  Veronica Lodge \n\nliterate/descriptive. canon...         False       en
# 26  @micmezle I don't watch but I saw this article...         False       en
# 50  RT @bettscoops: time jump betty is so &lt;3 ht...         False       en
#
#     favorite_count  retweet_count                time                   id
# 0                0             33 2021-02-26 23:41:49  1365447004848013316
# 1                0            509 2021-02-26 23:35:13  1365445344063029250
# 6                0             30 2021-02-26 23:14:18  1365440078877782016
# 17               0              2 2021-02-26 22:36:37  1365430596063870978
# 25               2              2 2021-02-26 22:13:36  1365424806573731840
# 26               0              0 2021-02-26 22:12:13  1365424455065853955
# 50               0             19 2021-02-26 20:57:22  1365405620313092096

# %%
df=df[df.language =="en"]

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                                               tweets  quote_status language  \
# 0  RT @BugheadUpdates: Time jump Jughead 👀 #River...         False       en
# 1  RT @SuperheroTVcom: VOTE: Riverdale Time Jump!...         False       en
# 2  RT @TheWyrmQueen: Toni Topaz \n\n-Riverdale rp...         False       en
# 3  RT @BusinessOfLodge: Veronica Lodge \n\nlitera...         False       en
# 4  Veronica Lodge \n\nliterate/descriptive. canon...         False       en
# 5  @micmezle I don't watch but I saw this article...         False       en
# 6  RT @bettscoops: time jump betty is so &lt;3 ht...         False       en
#
#    favorite_count  retweet_count                time                   id
# 0               0             33 2021-02-26 23:41:49  1365447004848013316
# 1               0            509 2021-02-26 23:35:13  1365445344063029250
# 2               0             30 2021-02-26 23:14:18  1365440078877782016
# 3               0              2 2021-02-26 22:36:37  1365430596063870978
# 4               2              2 2021-02-26 22:13:36  1365424806573731840
# 5               0              0 2021-02-26 22:12:13  1365424455065853955
# 6               0             19 2021-02-26 20:57:22  1365405620313092096

# %%
df.to_csv('time_jump.csv', index=False)
